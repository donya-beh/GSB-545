# %% [markdown]
# ## In Class Assignment April 9th

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\donya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\donya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scikit-learn) (1.17.1)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 2.1 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/8.1 MB 2.2 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.1 MB 2.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.1 MB 2.3 MB/s eta 0:00:03
#    ------------ --------------------------- 2.6/8.1 MB 2.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.4/8.1 MB 2.5 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 2.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/8.1 MB 2.5 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.1 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.1 MB 2.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.1 MB 2.3 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.1 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.1 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 2.0 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.1 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 1.8 MB/s  0:00:04
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    ---------------------------------------- 3/3 [scikit-learn]
#
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install sweetviz
# Out:
# Collecting sweetviz
#   Using cached sweetviz-2.3.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\donya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sweetviz) (3.0.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\donya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from sweetviz) (2.4.4)
# Collecting matplotlib>=3.1.3 (from sweetviz)
#   Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# Collecting tqdm>=4.43.0 (from sweetviz)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting scipy>=1.3.2 (from sweetviz)
#   Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting jinja2>=2.11.1 (from sweetviz)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting importlib_resources>=1.2.0 (from sweetviz)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.11.1->sweetviz)
#   Downloading markupsafe-3.0.3-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.1.3->sweetviz)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.1.3->sweetviz)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.1.3->sweetviz)
#   Downloading fonttools-4.62.1-cp314-cp314-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.1.3->sweetviz)
#   Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\donya\appdata\roaming\python\python314\site-packages (from matplotlib>=3.1.3->sweetviz) (26.0)
# Collecting pillow>=8 (from matplotlib>=3.1.3->sweetviz)
#   Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib>=3.1.3->sweetviz)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\donya\appdata\roaming\python\python314\site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\donya\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2026.1)
# Requirement already satisfied: six>=1.5 in c:\users\donya\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.17.0)
# Requirement already satisfied: colorama in c:\users\donya\appdata\roaming\python\python314\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Downloading sweetviz-2.3.2-py3-none-any.whl (15.1 MB)
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.1 MB 2.3 MB/s eta 0:00:07
#    --- ------------------------------------ 1.3/15.1 MB 3.6 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.8/15.1 MB 3.6 MB/s eta 0:00:04
#    ------ --------------------------------- 2.6/15.1 MB 3.3 MB/s eta 0:00:04
#    --------- ------------------------------ 3.4/15.1 MB 3.5 MB/s eta 0:00:04
#    ----------- ---------------------------- 4.5/15.1 MB 3.7 MB/s eta 0:00:03
#    ------------- -------------------------- 5.2/15.1 MB 3.7 MB/s eta 0:00:03
#    --------------- ------------------------ 6.0/15.1 MB 3.7 MB/s eta 0:00:03
#    ------------------ --------------------- 6.8/15.1 MB 3.8 MB/s eta 0:00:03
#    -------------------- ------------------- 7.9/15.1 MB 3.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.7/15.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------- -------------- 9.7/15.1 MB 3.9 MB/s eta 0:00:02
#    --------------------------- ------------ 10.5/15.1 MB 3.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.3/15.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 11.8/15.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 11.8/15.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 11.8/15.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 12.1/15.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 12.1/15.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 12.1/15.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 12.1/15.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 12.1/15.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 12.1/15.1 MB 3.2 MB/s eta 0:00:01
#    -------------------------------- ------- 12.3/15.1 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 12.3/15.1 MB 2.5 MB/s eta 0:00:02
#    --------------------------------- ------ 12.8/15.1 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 12.8/15.1 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.4/15.1 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 13.6/15.1 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------- -- 14.2/15.1 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 14.7/15.1 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 15.1/15.1 MB 2.3 MB/s  0:00:06
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp314-cp314-win_amd64.whl (15 kB)
# Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.3 MB 3.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/8.3 MB 3.2 MB/s eta 0:00:03
#    -------- ------------------------------- 1.8/8.3 MB 3.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.3 MB 2.9 MB/s eta 0:00:03
#    ------------- -------------------------- 2.9/8.3 MB 2.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.7/8.3 MB 3.0 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.3 MB 2.9 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.3 MB 3.0 MB/s eta 0:00:02
#    -------------------------- ------------- 5.5/8.3 MB 3.0 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.3 MB 3.1 MB/s eta 0:00:01
#    -------------------------------- ------- 6.8/8.3 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.3 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.3 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 2.9 MB/s  0:00:02
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 3.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.0/2.3 MB 3.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 3.0 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 2.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 2.1 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 695.9 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 735.6 kB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 788.6 kB/s  0:00:02
# Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.2 MB 2.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/7.2 MB 3.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.8/7.2 MB 3.2 MB/s eta 0:00:02
#    -------------- ------------------------- 2.6/7.2 MB 3.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.1/7.2 MB 3.1 MB/s eta 0:00:02
#    -------------------- ------------------- 3.7/7.2 MB 3.1 MB/s eta 0:00:02
#    --------------------- ------------------ 3.9/7.2 MB 2.9 MB/s eta 0:00:02
#    ------------------------ --------------- 4.5/7.2 MB 2.9 MB/s eta 0:00:01
#    --------------------------- ------------ 5.0/7.2 MB 2.7 MB/s eta 0:00:01
#    ------------------------------ --------- 5.5/7.2 MB 2.7 MB/s eta 0:00:01
#    ------------------------------- -------- 5.8/7.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.3/7.2 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 2.5 MB/s  0:00:02
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/37.3 MB ? eta -:--:--
#     --------------------------------------- 0.8/37.3 MB 2.0 MB/s eta 0:00:18
#    - -------------------------------------- 1.0/37.3 MB 1.9 MB/s eta 0:00:19
#    - -------------------------------------- 1.3/37.3 MB 1.7 MB/s eta 0:00:21
#    - -------------------------------------- 1.6/37.3 MB 1.6 MB/s eta 0:00:23
#    - -------------------------------------- 1.6/37.3 MB 1.6 MB/s eta 0:00:23
#    - -------------------------------------- 1.8/37.3 MB 1.4 MB/s eta 0:00:27
#    -- ------------------------------------- 2.1/37.3 MB 1.3 MB/s eta 0:00:29
#    -- ------------------------------------- 2.4/37.3 MB 1.2 MB/s eta 0:00:29
#    -- ------------------------------------- 2.6/37.3 MB 1.3 MB/s eta 0:00:28
#    --- ------------------------------------ 2.9/37.3 MB 1.3 MB/s eta 0:00:27
#    --- ------------------------------------ 3.4/37.3 MB 1.4 MB/s eta 0:00:25
#    ---- ----------------------------------- 3.9/37.3 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 3.9/37.3 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 3.9/37.3 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 3.9/37.3 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 3.9/37.3 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 3.9/37.3 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 3.9/37.3 MB 1.5 MB/s eta 0:00:23
#    ---- ----------------------------------- 4
101.7 MB 1.6 MB/s eta 0:00:22
#    -------------------------- ------------- 66.3/101.7 MB 1.7 MB/s eta 0:00:22
#    -------------------------- ------------- 66.3/101.7 MB 1.7 MB/s eta 0:00:22
#    -------------------------- ------------- 66.6/101.7 MB 1.7 MB/s eta 0:00:22
#    -------------------------- ------------- 67.1/101.7 MB 1.7 MB/s eta 0:00:21
#    -------------------------- ------------- 67.6/101.7 MB 1.7 MB/s eta 0:00:21
#    -------------------------- ------------- 67.9/101.7 MB 1.7 MB/s eta 0:00:21
#    -------------------------- ------------- 68.2/101.7 MB 1.7 MB/s eta 0:00:21
#    -------------------------- ------------- 68.2/101.7 MB 1.7 MB/s eta 0:00:21
#    -------------------------- ------------- 68.4/101.7 MB 1.7 MB/s eta 0:00:21
#    --------------------------- ------------ 68.7/101.7 MB 1.7 MB/s eta 0:00:20
#    --------------------------- ------------ 68.7/101.7 MB 1.7 MB/s eta 0:00:20
#    --------------------------- ------------ 68.9/101.7 MB 1.7 MB/s eta 0:00:20
#    --------------------------- ------------ 68.9/101.7 MB 1.7 MB/s eta 0:00:20
#    --------------------------- ------------ 68.9/101.7 MB 1.7 MB/s eta 0:00:20
#    --------------------------- ------------ 69.2/101.7 MB 1.6 MB/s eta 0:00:20
#    --------------------------- ------------ 69.5/101.7 MB 1.6 MB/s eta 0:00:20
#    --------------------------- ------------ 70.0/101.7 MB 1.6 MB/s eta 0:00:20
#    --------------------------- ------------ 70.3/101.7 MB 1.6 MB/s eta 0:00:20
#    --------------------------- ------------ 70.8/101.7 MB 1.6 MB/s eta 0:00:19
#    --------------------------- ------------ 71.0/101.7 MB 1.6 MB/s eta 0:00:19
#    ---------------------------- ----------- 71.6/101.7 MB 1.6 MB/s eta 0:00:19
#    ---------------------------- ----------- 71.8/101.7 MB 1.6 MB/s eta 0:00:19
#    ---------------------------- ----------- 72.6/101.7 MB 1.7 MB/s eta 0:00:18
#    ---------------------------- ----------- 73.1/101.7 MB 1.7 MB/s eta 0:00:18
#    ---------------------------- ----------- 73.7/101.7 MB 1.7 MB/s eta 0:00:17
#    ----------------------------- ---------- 74.2/101.7 MB 1.7 MB/s eta 0:00:17
#    ----------------------------- ---------- 75.0/101.7 MB 1.7 MB/s eta 0:00:16
#    ----------------------------- ---------- 75.8/101.7 MB 1.8 MB/s eta 0:00:15
#    ------------------------------ --------- 76.3/101.7 MB 1.8 MB/s eta 0:00:15
#    ------------------------------ --------- 77.1/101.7 MB 1.8 MB/s eta 0:00:14
#    ------------------------------ --------- 77.9/101.7 MB 1.8 MB/s eta 0:00:14
#    ------------------------------ --------- 78.6/101.7 MB 1.8 MB/s eta 0:00:13
#    ------------------------------- -------- 78.9/101.7 MB 1.8 MB/s eta 0:00:13
#    ------------------------------- -------- 79.2/101.7 MB 1.8 MB/s eta 0:00:13
#    ------------------------------- -------- 79.7/101.7 MB 1.8 MB/s eta 0:00:12
#    ------------------------------- -------- 80.0/101.7 MB 1.8 MB/s eta 0:00:12
#    ------------------------------- -------- 80.2/101.7 MB 1.8 MB/s eta 0:00:12
#    ------------------------------- -------- 80.5/101.7 MB 1.8 MB/s eta 0:00:12
#    ------------------------------- -------- 81.0/101.7 MB 1.8 MB/s eta 0:00:12
#    ------------------------------- -------- 81.3/101.7 MB 1.8 MB/s eta 0:00:12
#    -------------------------------- ------- 81.8/101.7 MB 1.9 MB/s eta 0:00:11
#    -------------------------------- ------- 81.8/101.7 MB 1.9 MB/s eta 0:00:11
#    -------------------------------- ------- 81.8/101.7 MB 1.9 MB/s eta 0:00:11
#    -------------------------------- ------- 81.8/101.7 MB 1.9 MB/s eta 0:00:11
#    -------------------------------- ------- 81.8/101.7 MB 1.9 MB/s eta 0:00:11
#    -------------------------------- ------- 82.1/101.7 MB 1.8 MB/s eta 0:00:11
#    -------------------------------- ------- 82.3/101.7 MB 1.8 MB/s eta 0:00:11
#    -------------------------------- ------- 82.6/101.7 MB 1.8 MB/s eta 0:00:11
#    -------------------------------- ------- 82.8/101.7 MB 1.8 MB/s eta 0:00:11
#    -------------------------------- ------- 83.4/101.7 MB 1.8 MB/s eta 0:00:11
#    -------------------------------- ------- 83.9/101.7 MB 1.8 MB/s eta 0:00:10
#    --------------------------------- ------ 84.4/101.7 MB 1.8 MB/s eta 0:00:10
#    --------------------------------- ------ 84.7/101.7 MB 1.8 MB/s eta 0:00:10
#    --------------------------------- ------ 84.7/101.7 MB 1.8 MB/s eta 0:00:10
#    --------------------------------- ------ 84.9/101.7 MB 1.8 MB/s eta 0:00:10
#    --------------------------------- ------ 85.2/101.7 MB 1.8 MB/s eta 0:00:10
#    --------------------------------- ------ 85.5/101.7 MB 1.8 MB/s eta 0:00:10
#    --------------------------------- ------ 85.5/101.7 MB 1.8 MB/s eta 0:00:10
#    --------------------------------- ------ 85.7/101.7 MB 1.8 MB/s eta 0:00:10
#    --------------------------------- ------ 85.7/101.7 MB 1.8 MB/s eta 0:00:10
#    --------------------------------- ------ 86.0/101.7 MB 1.8 MB/s eta 0:00:09
#    --------------------------------- ------ 86.2/101.7 MB 1.8 MB/s eta 0:00:09
#    ---------------------------------- ----- 86.5/101.7 MB 1.8 MB/s eta 0:00:09
#    ---------------------------------- ----- 86.8/101.7 MB 1.8 MB/s eta 0:00:09
#    ---------------------------------- ----- 87.3/101.7 MB 1.8 MB/s eta 0:00:09
#    ---------------------------------- ----- 87.6/101.7 MB 1.8 MB/s eta 0:00:08
#    ---------------------------------- ----- 88.1/101.7 MB 1.8 MB/s eta 0:00:08
#    ---------------------------------- ----- 88.6/101.7 MB 1.8 MB/s eta 0:00:08
#    ---------------------------------- ----- 88.9/101.7 MB 1.8 MB/s eta 0:00:08
#    ----------------------------------- ---- 89.4/101.7 MB 1.8 MB/s eta 0:00:07
#    ----------------------------------- ---- 89.9/101.7 MB 1.8 MB/s eta 0:00:07
#    ----------------------------------- ---- 90.2/101.7 MB 1.8 MB/s eta 0:00:07
#    ----------------------------------- ---- 90.7/101.7 MB 1.8 MB/s eta 0:00:07
#    ----------------------------------- ---- 91.2/101.7 MB 1.8 MB/s eta 0:00:06
#    ------------------------------------ --- 91.8/101.7 MB 1.9 MB/s eta 0:00:06
#    ------------------------------------ --- 92.0/101.7 MB 1.9 MB/s eta 0:00:06
#    ------------------------------------ --- 92.3/101.7 MB 1.9 MB/s eta 0:00:06
#    ------------------------------------ --- 92.5/101.7 MB 1.9 MB/s eta 0:00:05
#    ------------------------------------ --- 93.1/101.7 MB 1.9 MB/s eta 0:00:05
#    ------------------------------------ --- 93.3/101.7 MB 1.9 MB/s eta 0:00:05
#    ------------------------------------ --- 93.3/101.7 MB 1.9 MB/s eta 0:00:05
#    ------------------------------------ --- 93.3/101.7 MB 1.9 MB/s eta 0:00:05
#    ------------------------------------ --- 93.3/101.7 MB 1.9 MB/s eta 0:00:05
#    ------------------------------------ --- 93.6/101.7 MB 1.9 MB/s eta 0:00:05
#    ------------------------------------ --- 93.8/101.7 MB 1.9 MB/s eta 0:00:05
#    ------------------------------------- -- 94.1/101.7 MB 1.8 MB/s eta 0:00:05
#    ------------------------------------- -- 94.4/101.7 MB 1.8 MB/s eta 0:00:04
#    ------------------------------------- -- 94.6/101.7 MB 1.8 MB/s eta 0:00:04
#    ------------------------------------- -- 95.2/101.7 MB 1.8 MB/s eta 0:00:04
#    ------------------------------------- -- 95.7/101.7 MB 1.8 MB/s eta 0:00:04
#    ------------------------------------- -- 96.2/101.7 MB 1.8 MB/s eta 0:00:03
#    -------------------------------------- - 96.7/101.7 MB 1.8 MB/s eta 0:00:03
#    -------------------------------------- - 97.3/101.7 MB 1.8 MB/s eta 0:00:03
#    -------------------------------------- - 97.8/101.7 MB 1.8 MB/s eta 0:00:03
#    -------------------------------------- - 98.6/101.7 MB 1.8 MB/s eta 0:00:02
#    -------------------------------------- - 99.1/101.7 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------------  99.6/101.7 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------------  100.4/101.7 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  101.2/101.7 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  101.4/101.7 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  101.4/101.7 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 101.7/101.7 MB 1.8 MB/s  0:01:02
# Installing collected packages: xgboost
# Successfully installed xgboost-3.2.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import sweetviz as sv
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
# read in data
credit_card = pd.read_csv("C:\\Users\\donya\\Downloads\\creditcard.csv")
credit_card.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0     400000    1          1         2   32      0      0      0      0
# 1     120000    2          2         2   30     -1     -1     -1     -1
# 2     270000    2          2         2   32      0      0      0      0
# 3     280000    2          2         1   27      0      0      0      0
# 4      30000    2          1         2   27      0      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      48272      49478      51242      3028      3023      3000
# 1     -1  ...       1964       1883       1538      3230      3011      1964
# 2      0  ...      94856      86461      83650      1808     69563      2891
# 3      0  ...     257689     193231     191143     11052      9563     15017
# 4      0  ...       1814          0          0      1000       664      1500
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0      3000      3000     38662                           0
# 1      1883      1538      1911                           0
# 2      2689      3012      2771                           0
# 3      5374      5420      6021                           0
# 4         0         0         0                           0
#
# [5 rows x 24 columns]

# %% [markdown]
# #1

# %%
# EDA with sweetviz
report = sv.analyze(credit_card)
report.show_html("sweetviz_report.html")
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:01 -> (00:00 left)
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# Highlights from EDA
# - Limit balance skewed to the right with a median of $140,000
# - Age is skewed to the right with a median of 34 years old. All individuals in this data set are > 18 years old
# - All bill amounts are skewed to the right
# - The outcome variable, default payment next month, is imbalanced (individuals primarily will not default on their payment next month)

# %%
# define X and y
X = credit_card.drop("default payment next month", axis=1)
y = credit_card["default payment next month"]

# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=321)

#training random forest model (baseline)
rf = RandomForestClassifier(random_state=321)
rf.fit(X_train, y_train)

#evaluating random forest model
y_pred_rf = rf.predict(X_test)
print("Random Forest Classification Report:")
print(classification_report(y_test, y_pred_rf))
print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))

#with cross validation
cv_scores_rf = cross_val_score(rf, X, y, cv=5)
print("Random Forest Cross-Validation Scores:", cv_scores_rf)
print("Random Forest Average CV Score:", np.mean(cv_scores_rf))
print("Random Forest CV Score Standard Deviation:", np.std(cv_scores_rf))

#training xgboost model (baseline)
xgb = XGBClassifier(random_state=321, use_label_encoder=False, eval_metric='logloss')
xgb.fit(X_train, y_train)

#evaluating xgboost model
y_pred_xgb = xgb.predict(X_test)
print("XGBoost Classification Report:")
print(classification_report(y_test, y_pred_xgb))
print("XGBoost Accuracy:", accuracy_score(y_test, y_pred_xgb))

#with cross validation
cv_scores_xgb = cross_val_score(xgb, X, y, cv=5)
print("XGBoost Cross-Validation Scores:", cv_scores_xgb)
print("XGBoost Average CV Score:", np.mean(cv_scores_xgb))
print("XGBoost CV Score Standard Deviation:", np.std(cv_scores_xgb))
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      3704
#            1       0.68      0.40      0.51      1096
#
#     accuracy                           0.82      4800
#    macro avg       0.76      0.67      0.70      4800
# weighted avg       0.81      0.82      0.80      4800
#
# Random Forest Accuracy: 0.8210416666666667
# Random Forest Cross-Validation Scores: [0.81229167 0.81041667 0.81395833 0.81145833 0.81958333]
# Random Forest Average CV Score: 0.8135416666666666
# Random Forest CV Score Standard Deviation: 0.003235544776386203
# c:\Users\donya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\xgboost\training.py:200: UserWarning: [17:27:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      3704
#            1       0.67      0.40      0.50      1096
#
#     accuracy                           0.82      4800
#    macro avg       0.75      0.67      0.70      4800
# weighted avg       0.80      0.82      0.80      4800
#
# XGBoost Accuracy: 0.8177083333333334
# c:\Users\donya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\xgboost\training.py:200: UserWarning: [17:27:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\donya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\xgboost\training.py:200: UserWarning: [17:27:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\donya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\xgboost\training.py:200: UserWarning: [17:27:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\donya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\xgboost\training.py:200: UserWarning: [17:27:53] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\donya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\xgboost\training.py:200: UserWarning: [17:27:53] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost Cross-Validation Scores: [0.80979167 0.81083333 0.814375   0.81020833 0.81895833]
# XGBoost Average CV Score: 0.8128333333333334
# XGBoost CV Score Standard Deviation: 0.00346510381438197

# %% [markdown]
# #2
# - Both models perform well in terms of accuracy (~ 0.80 for each). However it seems like due to the imbalance in the dataset, the models' high accuracy scores are likely being dominated by correct classifications of individuals who will not default on their payment the next month (outcome = 0). We can see this in the lower recall and precision scores for both models for the outcome = 0 group compared to the outcome = 1 (defaults on payment the next month) group
#
# - The average accuracy scores and standard deviation for the cross-validated models are very similar between both the Random Forest and XGBoost models. We see accuracy scores that are consistently around 0.80 for both models with not much deviation. Due to the imbalanced data, we are likely obtaining folds of data that are primarily representing individuals who do not default on the next month's payment. This may explain the small deviation in accuracy score across the five folds. The model is consistently performing well at classifying our default = 1 cases.
#
# #3
# - Yes, as I mentioned in #2, the accuracy score seems to be high due to the model primarily correctly classifying individuals who will not default on next month's payment compared to those who will default. This is likely because of the imbalanced nature of the dataset. There are more individuals who do not actually default in the next month's payment, so these classifications are captured more by our models

# %% [markdown]
# #4

# %%
#adjust for class imbalance in random forest model
rf_balanced = RandomForestClassifier(random_state=321, class_weight='balanced')
rf_balanced.fit(X_train, y_train)
y_pred_rf_balanced = rf_balanced.predict(X_test)
print("Random Forest (Balanced) Classification Report:")
print(classification_report(y_test, y_pred_rf_balanced))

#adjust for class imbalance in xgboost model
xgb_balanced = XGBClassifier(random_state=321, use_label_encoder=False, eval_metric='logloss', scale_pos_weight=10)
xgb_balanced.fit(X_train, y_train)
y_pred_xgb_balanced = xgb_balanced.predict(X_test)
print("XGBoost (Balanced) Classification Report:")
print(classification_report(y_test, y_pred_xgb_balanced))
# Out:
# Random Forest (Balanced) Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      3704
#            1       0.71      0.37      0.49      1096
#
#     accuracy                           0.82      4800
#    macro avg       0.77      0.66      0.69      4800
# weighted avg       0.81      0.82      0.80      4800
# c:\Users\donya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\xgboost\training.py:200: UserWarning: [17:43:48] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost (Balanced) Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.62      0.73      3704
#            1       0.36      0.74      0.49      1096
#
#     accuracy                           0.65      4800
#    macro avg       0.63      0.68      0.61      4800
# weighted avg       0.77      0.65      0.68      4800

# %% [markdown]
# - The accuracy did not change for the random forest balanced model, but the precision score increased for classification of individuals who will default on the next month's payment. However, the recall score decreased meaning that the model struggled with correctly classifying individuals who default correctly.
#
# - Interestingly, we see accuracy decrease when accounting for class imbalance with XGBoost. The classification report of this model is quite different from the random forest balanced model. In this model, the recall increased substantially but decreased quite a bit as well in terms of precision. This indicates that of individuals who actually defaulted, the model was able to capture 74% (high accuracy) of them but there are many false positives-individuals who were classified as defaulting but they actually did not default (low precision).

# %% [markdown]
# #5

# %%
#XGBoost model with subsample feature
xgb_subsample = XGBClassifier(random_state=321, use_label_encoder=False, eval_metric='logloss', subsample=0.8)
xgb_subsample.fit(X_train, y_train)
y_pred_xgb_subsample = xgb_subsample.predict(X_test)
print("XGBoost (Subsample) Classification Report:")
print(classification_report(y_test, y_pred_xgb_subsample))
# Out:
# c:\Users\donya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\xgboost\training.py:200: UserWarning: [17:51:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost (Subsample) Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      3704
#            1       0.65      0.40      0.49      1096
#
#     accuracy                           0.81      4800
#    macro avg       0.74      0.67      0.69      4800
# weighted avg       0.80      0.81      0.80      4800

# %% [markdown]
# - The model's accuracy is close to the original XGBoost model without any subsampling
#
# - Both precision and recall have increased for the defaulted = 1 outcome compared to the original XGBoost model. This indicates that the model with subsampling is better able to classify individuals who default on their payments in the next month

# %% [markdown]
# #6

# %%
#tuning 2 hyperparameters with 2 values for Random Forest using imbalance adjustments
param_grid_rf = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10]
}
grid_rf = GridSearchCV(estimator=rf_balanced, param_grid=param_grid_rf, cv=5, n_jobs=-1)
grid_rf.fit(X_train, y_train)
print("Best Hyperparameters for Random Forest:", grid_rf.best_params_)
best_rf = grid_rf.best_estimator_
y_pred_best_rf = best_rf.predict(X_test)
print("Tuned Random Forest Classification Report:")
print(classification_report(y_test, y_pred_best_rf))

#tuning 2 hyperparameters with 2 values for XGBoost using imbalance adjustments
param_grid_xgb = {
    'n_estimators': [100, 200],
    'max_depth': [3, 6]
}
grid_xgb = GridSearchCV(estimator=xgb_balanced, param_grid=param_grid_xgb, cv=5, n_jobs=-1)
grid_xgb.fit(X_train, y_train)
print("Best Hyperparameters for XGBoost:", grid_xgb.best_params_)
best_xgb = grid_xgb.best_estimator_
y_pred_best_xgb = best_xgb.predict(X_test)
print("Tuned XGBoost Classification Report:")
print(classification_report(y_test, y_pred_best_xgb))
# Out:
# Best Hyperparameters for Random Forest: {'max_depth': None, 'n_estimators': 200}
# Tuned Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      3704
#            1       0.70      0.36      0.48      1096
#
#     accuracy                           0.82      4800
#    macro avg       0.77      0.66      0.69      4800
# weighted avg       0.80      0.82      0.80      4800
# c:\Users\donya\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\xgboost\training.py:200: UserWarning: [17:58:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best Hyperparameters for XGBoost: {'max_depth': 6, 'n_estimators': 200}
# Tuned XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.73      0.79      3704
#            1       0.41      0.64      0.50      1096
#
#     accuracy                           0.71      4800
#    macro avg       0.64      0.68      0.65      4800
# weighted avg       0.77      0.71      0.73      4800

# %% [markdown]
# - The random forest model's accuracy score is the same as the default random forest's accuracy score. However, we see that this model's precision score for default = 1 has increased compared to the default model but also decreased in terms of its recall. Therefore, of everyone the model predicted as defaulting on next month's payment, the model is able to capture a 70% of individuals who actually did default, but still incorrectly classifying those who defaulted as individuals who did not default.
#
# - The accuracy score for the balanced XGBoost model has decreased compared to the default model. The precision score for default = 1 has decreased, while the recall score for this group has increased. This indicates that 64% of individuals are classified correctly as defaulting, but of all the individuals the model predicted would default, only 41% actually defaulted.
#
# - Given the time constraints (and therefore limited time to tune models) of this in-class activity and the fact that each model's performance did not seem to substantially improve from the default models, it is likely that I did not chose the right parameters to tune. There is much more exploration into the vast amount of parameters that I can take to find the optimal model for each model type.

# %% [markdown]
# #7
#
# Using the default settings, the random forest classification model performs slightly better than the XGBoost model. If we look at the F1-score of the default = 1 group (takes into account the scores of both precision and recall), we can see that the random forest classification model has the higher score of 0.51 compared to the XGBoost model with an F1-score of 0.50. This is likely because the random forest classification model performs slightly better in terms of precision for this group compared to the XGBoost model (0.68 vs. 0.67). This indicates that the 68% of individuals who are classified as defaulting on next month's payment are actually classified correctly, compared to 67% for the XGBoost model.
