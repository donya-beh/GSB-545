# %% [markdown]
# # Day 2 RNN

# %% [markdown]
# ### Importing libraries

# %%
# Libraries

import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU, Dropout
from tensorflow.keras.callbacks import EarlyStopping

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Load & inspect data

# %%
# Load and inspect Bitcoin data

bitcoin = pd.read_csv("dc.csv")

bitcoin = bitcoin.rename(
    columns={"Unnamed: 0": "date"}
)

bitcoin["date"] = pd.to_datetime(bitcoin["date"])

bitcoin = (
    bitcoin
    .sort_values("date")
    .reset_index(drop=True)
)

print(bitcoin.shape)

bitcoin.head()
# Out:
# (1000, 6)
#         date  open_USD  \
# 0 2018-05-07   9661.02
# 1 2018-05-08   9365.00
# 2 2018-05-09   9178.00
# 3 2018-05-10   9310.00
# 4 2018-05-11   9002.21
#
#    high_USD  low_USD  \
# 0   9689.67  9181.00
# 1   9475.70  9060.54
# 2   9390.00  8965.00
# 3   9395.12  8970.00
# 4   9016.80  8341.00
#
#    close_USD  volume
# 0    9365.00   33787
# 1    9187.56   25533
# 2    9310.00   25673
# 3    9002.20   25055
# 4    8400.00   48227

# %%
# Basic inspection

bitcoin.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1000 non-null   datetime64[us]
#  1   open_USD   1000 non-null   float64
#  2   high_USD   1000 non-null   float64
#  3   low_USD    1000 non-null   float64
#  4   close_USD  1000 non-null   float64
#  5   volume     1000 non-null   int64
# dtypes: datetime64[us](1), float64(4), int64(1)
# memory usage: 47.0 KB

# %%
# Summary statistics

bitcoin.describe()
# Out:
#                       date  \
# count                 1000
# mean   2019-09-18 12:00:00
# min    2018-05-07 00:00:00
# 25%    2019-01-11 18:00:00
# 50%    2019-09-18 12:00:00
# 75%    2020-05-25 06:00:00
# max    2021-01-30 00:00:00
# std                    NaN
#
#            open_USD  \
# count   1000.000000
# mean    9285.762120
# min     3211.710000
# 25%     6467.192500
# 50%     8189.695000
# 75%    10216.860000
# max    40586.960000
# std     5793.522832
#
#            high_USD  \
# count   1000.000000
# mean    9542.880270
# min     3276.500000
# 25%     6582.255000
# 50%     8351.630000
# 75%    10419.562500
# max    41950.000000
# std     6075.604427
#
#             low_USD  \
# count   1000.000000
# mean    9011.393200
# min     3156.260000
# 25%     6325.015000
# 50%     8002.045000
# 75%     9907.977500
# max    38720.000000
# std     5483.524463
#
#           close_USD  \
# count   1000.000000
# mean    9310.335850
# min     3211.720000
# 25%     6466.762500
# 50%     8189.330000
# 75%    10220.170000
# max    40582.810000
# std     5846.917681
#
#               volume
# count    1000.000000
# mean    53100.498000
# min      5743.000000
# 25%     30045.750000
# 50%     43795.500000
# 75%     64909.250000
# max    402201.000000
# std     35329.832031

# %% [markdown]
# Visualizing the target variable

# %%
# Visualize closing price over time

plt.figure(figsize=(10, 4))

plt.plot(
    bitcoin["date"],
    bitcoin["close_USD"]
)

plt.title("Bitcoin Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price (USD)")

plt.ticklabel_format(
    style="plain",
    axis="y"
)

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Preparing data for recurrent modeling

# %%
# Prepare Bitcoin data for recurrent models

features = [
    "open_USD",
    "high_USD",
    "low_USD",
    "close_USD",
    "volume"
]

target_col = "close_USD"

bitcoin_model = bitcoin[["date"] + features].copy()

print("Unique dates:", bitcoin_model["date"].nunique())
print("Rows:", len(bitcoin_model))

scaler_bitcoin = MinMaxScaler(feature_range=(0, 1))

scaled_features = scaler_bitcoin.fit_transform(
    bitcoin_model[features]
)

look_back = 10                                                  # use 10 previous days to predict next close

target_index = features.index(target_col)
# Out:
# Unique dates: 1000
# Rows: 1000

# %% [markdown]
# ### Useful functions

# %%
# Function to create recurrent sequence windows

def create_sequences(dataset, target_index, look_back=10):

    X, y = [], []

    for i in range(len(dataset) - look_back):

        X.append(
            dataset[i:i + look_back, :]
        )                                                       # previous look_back days

        y.append(
            dataset[i + look_back, target_index]
        )                                                       # next day's close_USD

    return np.array(X), np.array(y)

# %%
# Function to visualize training curves

def plot_training_curves(history, title):

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    # Loss
    axes[0].plot(
        history.history["loss"],
        label="Training Loss"
    )

    axes[0].plot(
        history.history["val_loss"],
        label="Validation Loss"
    )

    axes[0].set_title(title + " Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("MSE Loss")

    axes[0].legend()

    # MAE
    axes[1].plot(
        history.history["mean_absolute_error"],
        label="Training MAE"
    )

    axes[1].plot(
        history.history["val_mean_absolute_error"],
        label="Validation MAE"
    )

    axes[1].set_title(title + " MAE")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Mean Absolute Error")

    axes[1].legend()

    plt.tight_layout()

    plt.show()

# %%
# Function to evaluate forecasting performance

def evaluate_and_plot(
    model,
    trainX,
    testX,
    trainY,
    testY,
    scaler,
    target_index,
    title
):

    # Predictions
    train_pred = model.predict(trainX)
    test_pred = model.predict(testX)

    # Create arrays for inverse scaling
    train_dummy = np.zeros((len(train_pred), len(features)))
    test_dummy = np.zeros((len(test_pred), len(features)))

    train_dummy[:, target_index] = train_pred.flatten()
    test_dummy[:, target_index] = test_pred.flatten()

    trainY_dummy = np.zeros((len(trainY), len(features)))
    testY_dummy = np.zeros((len(testY), len(features)))

    trainY_dummy[:, target_index] = trainY
    testY_dummy[:, target_index] = testY

    # Inverse transform
    train_pred_inv = scaler.inverse_transform(train_dummy)[:, target_index]
    test_pred_inv = scaler.inverse_transform(test_dummy)[:, target_index]

    trainY_inv = scaler.inverse_transform(trainY_dummy)[:, target_index]
    testY_inv = scaler.inverse_transform(testY_dummy)[:, target_index]

    # Metrics
    train_rmse = np.sqrt(mean_squared_error(trainY_inv, train_pred_inv))
    test_rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))

    train_mae = mean_absolute_error(trainY_inv, train_pred_inv)
    test_mae = mean_absolute_error(testY_inv, test_pred_inv)

    print(f"{title} Train RMSE: {train_rmse:.2f}")
    print(f"{title} Test RMSE: {test_rmse:.2f}")

    print(f"{title} Train MAE: {train_mae:.2f}")
    print(f"{title} Test MAE: {test_mae:.2f}")

    # Plot predictions
    plt.figure(figsize=(10, 4))

    plt.plot(
        testY_inv,
        label="Actual"
    )

    plt.plot(
        test_pred_inv,
        label="Predicted"
    )

    plt.title(title + " Test Predictions")

    plt.xlabel("Test time index")
    plt.ylabel("Bitcoin Close Price (USD)")

    plt.ticklabel_format(
        style="plain",
        axis="y"
    )

    plt.legend()

    plt.show()

# %%
# Function to compare model metrics

def evaluate_metrics(
    model,
    testX,
    testY,
    scaler,
    target_index
):

    test_pred = model.predict(testX)

    test_dummy = np.zeros((len(test_pred), len(features)))
    test_dummy[:, target_index] = test_pred.flatten()

    testY_dummy = np.zeros((len(testY), len(features)))
    testY_dummy[:, target_index] = testY

    test_pred_inv = scaler.inverse_transform(test_dummy)[:, target_index]
    testY_inv = scaler.inverse_transform(testY_dummy)[:, target_index]

    rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))
    mae = mean_absolute_error(testY_inv, test_pred_inv)

    return rmse, mae

# %% [markdown]
# ### Creating train/test recurrent tensors

# %%
# Create train/test recurrent tensors

train_size = int(len(scaled_features) * 0.8)                    # chronological 80/20 split

train_bitcoin = scaled_features[:train_size]                    # earlier data
test_bitcoin = scaled_features[train_size:]                     # held-out future data

trainX_bitcoin, trainY_bitcoin = create_sequences(
    train_bitcoin,
    target_index,
    look_back
)

testX_bitcoin, testY_bitcoin = create_sequences(
    test_bitcoin,
    target_index,
    look_back
)

print("trainX_bitcoin shape:", trainX_bitcoin.shape)
print("testX_bitcoin shape:", testX_bitcoin.shape)
print("trainY_bitcoin shape:", trainY_bitcoin.shape)
print("testY_bitcoin shape:", testY_bitcoin.shape)
# Out:
# trainX_bitcoin shape: (790, 10, 5)
# testX_bitcoin shape: (190, 10, 5)
# trainY_bitcoin shape: (790,)
# testY_bitcoin shape: (190,)

# %% [markdown]
# ### Baseline SimpleRNN model

# %%
# Build and train baseline SimpleRNN model

simple_rnn_model = Sequential([
    SimpleRNN(
        8,                                     # small baseline recurrent layer
        activation="tanh",                     # standard activation for SimpleRNN
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

simple_rnn_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

simple_rnn_history = simple_rnn_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0108 - mean_absolute_error: 0.0820 - val_loss: 0.0113 - val_mean_absolute_error: 0.0747
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0041 - mean_absolute_error: 0.0477 - val_loss: 0.0080 - val_mean_absolute_error: 0.0571
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0029 - mean_absolute_error: 0.0402 - val_loss: 0.0062 - val_mean_absolute_error: 0.0496
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0343 - val_loss: 0.0049 - val_mean_absolute_error: 0.0438
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0304 - val_loss: 0.0039 - val_mean_absolute_error: 0.0391
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - mean_absolute_error: 0.0279 - val_loss: 0.0032 - val_mean_absolute_error: 0.0353
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - mean_absolute_error: 0.0259 - val_loss: 0.0026 - val_mean_absolute_error: 0.0323
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 0.0022 - val_mean_absolute_error: 0.0299
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6651e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0019 - val_mean_absolute_error: 0.0280
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5578e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0016 - val_mean_absolute_error: 0.0264
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 7.6079e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0014 - val_mean_absolute_error: 0.0250
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7854e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0013 - val_mean_absolute_error: 0.0239
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.0700e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0012 - val_mean_absolute_error: 0.0228
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4465e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0010 - val_mean_absolute_error: 0.0218
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9029e-04 - mean_absolute_error: 0.0163 - val_loss: 9.4630e-04 - val_mean_absolute_error: 0.0208
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4292e-04 - mean_absolute_error: 0.0155 - val_loss: 8.6039e-04 - val_mean_absolute_error: 0.0199
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0168e-04 - mean_absolute_error: 0.0148 - val_loss: 7.8424e-04 - val_mean_absolute_error: 0.0190
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6580e-04 - mean_absolute_error: 0.0141 - val_loss: 7.1639e-04 - val_mean_absolute_error: 0.0182
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3461e-04 - mean_absolute_error: 0.0135 - val_loss: 6.5577e-04 - val_mean_absolute_error: 0.0174
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0751e-04 - mean_absolute_error: 0.0130 - val_loss: 6.0155e-04 - val_mean_absolute_error: 0.0166
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8395e-04 - mean_absolute_error: 0.0125 - val_loss: 5.5307e-04 - val_mean_absolute_error: 0.0159
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6346e-04 - mean_absolute_error: 0.0121 - val_loss: 5.0976e-04 - val_mean_absolute_error: 0.0153
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4563e-04 - mean_absolute_error: 0.0116 - val_loss: 4.7113e-04 - val_mean_absolute_error: 0.0147
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3011e-04 - mean_absolute_error: 0.0113 - val_loss: 4.3671e-04 - val_mean_absolute_error: 0.0142
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1657e-04 - mean_absolute_error: 0.0109 - val_loss: 4.0609e-04 - val_mean_absolute_error: 0.0137
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0475e-04 - mean_absolute_error: 0.0106 - val_loss: 3.7890e-04 - val_mean_absolute_error: 0.0133
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9443e-04 - mean_absolute_error: 0.0104 - val_loss: 3.5479e-04 - val_mean_absolute_error: 0.0129
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8540e-04 - mean_absolute_error: 0.0101 - val_loss: 3.3342e-04 - val_mean_absolute_error: 0.0125
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 1.7750e-04 - mean_absolute_error: 0.0099 - val_loss: 3.1452e-04 - val_mean_absolute_error: 0.0122
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 1.7058e-04 - mean_absolute_error: 0.0097 - val_loss: 2.9782e-04 - val_mean_absolute_error: 0.0118
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6452e-04 - mean_absolute_error: 0.0095 - val_loss: 2.8306e-04 - val_mean_absolute_error: 0.0115
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 1.5921e-04 - mean_absolute_error: 0.0093 - val_loss: 2.7003e-04 - val_mean_absolute_error: 0.0113
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5456e-04 - mean_absolute_error: 0.0091 - val_loss: 2.5853e-04 - val_mean_absolute_error: 0.0110
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 1.5048e-04 - mean_absolute_error: 0.0090 - val_loss: 2.4838e-04 - val_mean_absolute_error: 0.0108
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4691e-04 - mean_absolute_error: 0.0089 - val_loss: 2.3943e-04 - val_mean_absolute_error: 0.0106
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4377e-04 - mean_absolute_error: 0.0087 - val_loss: 2.3152e-04 - val_mean_absolute_error: 0.0104
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4101e-04 - mean_absolute_error: 0.0086 - val_loss: 2.2454e-04 - val_mean_absolute_error: 0.0102
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 1.3859e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1838e-04 - val_mean_absolute_error: 0.0100
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3645e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1293e-04 - val_mean_absolute_error: 0.0099
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 1.3457e-04 - mean_absolute_error: 0.0084 - val_loss: 2.0810e-04 - val_mean_absolute_error: 0.0098
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3290e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0383e-04 - val_mean_absolute_error: 0.0097
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3141e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0004e-04 - val_mean_absolute_error: 0.0096
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3007e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9668e-04 - val_mean_absolute_error: 0.0095
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 1.2886e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9370e-04 - val_mean_absolute_error: 0.0094
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2777e-04 - mean_absolute_error: 0.0081 - val_loss: 1.9105e-04 - val_mean_absolute_error: 0.0094
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2677e-04 - mean_absolute_error: 0.0081 - val_loss: 1.8868e-04 - val_mean_absolute_error: 0.0093
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 1.2584e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8659e-04 - val_mean_absolute_error: 0.0093
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 1.2498e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8472e-04 - val_mean_absolute_error: 0.0092
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 1.2417e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8307e-04 - val_mean_absolute_error: 0.0092
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 1.2341e-04 - mean_absolute_error: 0.0079 - val_loss: 1.8160e-04 - val_mean_absolute_error: 0.0091

# %% [markdown]
# Visualizing training

# %%
# Visualize SimpleRNN training performance

plot_training_curves(
    simple_rnn_history,
    "Baseline SimpleRNN"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate SimpleRNN on held-out future test data

evaluate_and_plot(
    simple_rnn_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline SimpleRNN"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Baseline SimpleRNN Train RMSE: 493.52
# Baseline SimpleRNN Test RMSE: 3953.11
# Baseline SimpleRNN Train MAE: 364.83
# Baseline SimpleRNN Test MAE: 2409.82

# %% [markdown]
# ### Baseline LSTM Model

# %%
# Build and train baseline LSTM model

lstm_model = Sequential([
    LSTM(
        8,                                     # small baseline LSTM layer
        activation="tanh",                     # standard LSTM hidden-state activation
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

lstm_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

lstm_history = lstm_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0332 - val_loss: 0.0052 - val_mean_absolute_error: 0.0536
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0257 - val_loss: 0.0043 - val_mean_absolute_error: 0.0484
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.7141e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0033 - val_mean_absolute_error: 0.0409
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8698e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0024 - val_mean_absolute_error: 0.0340
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2297e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0019 - val_mean_absolute_error: 0.0293
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8944e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0015 - val_mean_absolute_error: 0.0259
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6544e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0012 - val_mean_absolute_error: 0.0231
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4755e-04 - mean_absolute_error: 0.0122 - val_loss: 9.9588e-04 - val_mean_absolute_error: 0.0206
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3489e-04 - mean_absolute_error: 0.0118 - val_loss: 8.1265e-04 - val_mean_absolute_error: 0.0184
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2655e-04 - mean_absolute_error: 0.0116 - val_loss: 6.7026e-04 - val_mean_absolute_error: 0.0165
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2148e-04 - mean_absolute_error: 0.0114 - val_loss: 5.6249e-04 - val_mean_absolute_error: 0.0149
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1859e-04 - mean_absolute_error: 0.0112 - val_loss: 4.8299e-04 - val_mean_absolute_error: 0.0137
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1692e-04 - mean_absolute_error: 0.0111 - val_loss: 4.2545e-04 - val_mean_absolute_error: 0.0128
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1573e-04 - mean_absolute_error: 0.0110 - val_loss: 3.8417e-04 - val_mean_absolute_error: 0.0121
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1456e-04 - mean_absolute_error: 0.0110 - val_loss: 3.5447e-04 - val_mean_absolute_error: 0.0117
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1317e-04 - mean_absolute_error: 0.0109 - val_loss: 3.3280e-04 - val_mean_absolute_error: 0.0113
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1150e-04 - mean_absolute_error: 0.0108 - val_loss: 3.1663e-04 - val_mean_absolute_error: 0.0110
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0954e-04 - mean_absolute_error: 0.0108 - val_loss: 3.0425e-04 - val_mean_absolute_error: 0.0107
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0735e-04 - mean_absolute_error: 0.0107 - val_loss: 2.9449e-04 - val_mean_absolute_error: 0.0106
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0497e-04 - mean_absolute_error: 0.0106 - val_loss: 2.8657e-04 - val_mean_absolute_error: 0.0104
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0247e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7997e-04 - val_mean_absolute_error: 0.0103
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9988e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7434e-04 - val_mean_absolute_error: 0.0101
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9723e-04 - mean_absolute_error: 0.0104 - val_loss: 2.6942e-04 - val_mean_absolute_error: 0.0100
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9457e-04 - mean_absolute_error: 0.0103 - val_loss: 2.6506e-04 - val_mean_absolute_error: 0.0100
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9189e-04 - mean_absolute_error: 0.0102 - val_loss: 2.6112e-04 - val_mean_absolute_error: 0.0099
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8924e-04 - mean_absolute_error: 0.0101 - val_loss: 2.5753e-04 - val_mean_absolute_error: 0.0098
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8660e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5422e-04 - val_mean_absolute_error: 0.0098
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8401e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5114e-04 - val_mean_absolute_error: 0.0097
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8147e-04 - mean_absolute_error: 0.0099 - val_loss: 2.4826e-04 - val_mean_absolute_error: 0.0097
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7897e-04 - mean_absolute_error: 0.0098 - val_loss: 2.4556e-04 - val_mean_absolute_error: 0.0097
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7653e-04 - mean_absolute_error: 0.0097 - val_loss: 2.4301e-04 - val_mean_absolute_error: 0.0096
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7416e-04 - mean_absolute_error: 0.0096 - val_loss: 2.4059e-04 - val_mean_absolute_error: 0.0096
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7184e-04 - mean_absolute_error: 0.0096 - val_loss: 2.3830e-04 - val_mean_absolute_error: 0.0096
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6959e-04 - mean_absolute_error: 0.0095 - val_loss: 2.3612e-04 - val_mean_absolute_error: 0.0095
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6740e-04 - mean_absolute_error: 0.0094 - val_loss: 2.3405e-04 - val_mean_absolute_error: 0.0095
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6527e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3207e-04 - val_mean_absolute_error: 0.0095
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6321e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3019e-04 - val_mean_absolute_error: 0.0095
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6121e-04 - mean_absolute_error: 0.0092 - val_loss: 2.2839e-04 - val_mean_absolute_error: 0.0095
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5927e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2666e-04 - val_mean_absolute_error: 0.0094
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5739e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2501e-04 - val_mean_absolute_error: 0.0094
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5557e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2343e-04 - val_mean_absolute_error: 0.0094
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5381e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2191e-04 - val_mean_absolute_error: 0.0094
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5210e-04 - mean_absolute_error: 0.0089 - val_loss: 2.2045e-04 - val_mean_absolute_error: 0.0094
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5044e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1904e-04 - val_mean_absolute_error: 0.0094
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4884e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1768e-04 - val_mean_absolute_error: 0.0094
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4728e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1637e-04 - val_mean_absolute_error: 0.0094
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4577e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1510e-04 - val_mean_absolute_error: 0.0094
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4431e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1387e-04 - val_mean_absolute_error: 0.0094
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4289e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1267e-04 - val_mean_absolute_error: 0.0094
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4151e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1150e-04 - val_mean_absolute_error: 0.0094

# %% [markdown]
# Visualizing training

# %%
# Visualize LSTM training performance

plot_training_curves(
    lstm_history,
    "Baseline LSTM"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate LSTM on held-out future test data

evaluate_and_plot(
    lstm_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline LSTM"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Baseline LSTM Train RMSE: 434.39
# Baseline LSTM Test RMSE: 2398.13
# Baseline LSTM Train MAE: 299.69
# Baseline LSTM Test MAE: 1580.11

# %% [markdown]
# Slightly better to use LSTM but note how smooth the curve is. We are losing signal so we might want to use a smaller lookback.

# %% [markdown]
# ### Baseline GRU model

# %%
# Build and train baseline GRU model

gru_model = Sequential([
    GRU(
        8,                                      # intentionally small baseline GRU layer
        activation="tanh",                     # standard GRU hidden-state activation
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

gru_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

gru_history = gru_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0039 - mean_absolute_error: 0.0515 - val_loss: 0.0022 - val_mean_absolute_error: 0.0363
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0279 - val_loss: 0.0020 - val_mean_absolute_error: 0.0395
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3650e-04 - mean_absolute_error: 0.0147 - val_loss: 8.5610e-04 - val_mean_absolute_error: 0.0239
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5692e-04 - mean_absolute_error: 0.0092 - val_loss: 3.7739e-04 - val_mean_absolute_error: 0.0138
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6610e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3522e-04 - val_mean_absolute_error: 0.0105
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8008e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7585e-04 - val_mean_absolute_error: 0.0090
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8698e-04 - mean_absolute_error: 0.0096 - val_loss: 1.4778e-04 - val_mean_absolute_error: 0.0082
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8542e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3687e-04 - val_mean_absolute_error: 0.0079
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7644e-04 - mean_absolute_error: 0.0094 - val_loss: 1.3468e-04 - val_mean_absolute_error: 0.0080
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6288e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3660e-04 - val_mean_absolute_error: 0.0083
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4787e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4010e-04 - val_mean_absolute_error: 0.0085
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3379e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4387e-04 - val_mean_absolute_error: 0.0088
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2194e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4737e-04 - val_mean_absolute_error: 0.0090
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1275e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5053e-04 - val_mean_absolute_error: 0.0091
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0608e-04 - mean_absolute_error: 0.0074 - val_loss: 1.5349e-04 - val_mean_absolute_error: 0.0093
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0154e-04 - mean_absolute_error: 0.0072 - val_loss: 1.5648e-04 - val_mean_absolute_error: 0.0094
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8688e-05 - mean_absolute_error: 0.0071 - val_loss: 1.5971e-04 - val_mean_absolute_error: 0.0096
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.7116e-05 - mean_absolute_error: 0.0070 - val_loss: 1.6333e-04 - val_mean_absolute_error: 0.0098
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6519e-05 - mean_absolute_error: 0.0070 - val_loss: 1.6747e-04 - val_mean_absolute_error: 0.0100
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6686e-05 - mean_absolute_error: 0.0070 - val_loss: 1.7219e-04 - val_mean_absolute_error: 0.0102
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7492e-05 - mean_absolute_error: 0.0070 - val_loss: 1.7759e-04 - val_mean_absolute_error: 0.0104
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8869e-05 - mean_absolute_error: 0.0071 - val_loss: 1.8374e-04 - val_mean_absolute_error: 0.0107
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0079e-04 - mean_absolute_error: 0.0072 - val_loss: 1.9071e-04 - val_mean_absolute_error: 0.0111
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0323e-04 - mean_absolute_error: 0.0073 - val_loss: 1.9856e-04 - val_mean_absolute_error: 0.0114
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0620e-04 - mean_absolute_error: 0.0074 - val_loss: 2.0731e-04 - val_mean_absolute_error: 0.0117
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0967e-04 - mean_absolute_error: 0.0076 - val_loss: 2.1692e-04 - val_mean_absolute_error: 0.0121
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1360e-04 - mean_absolute_error: 0.0078 - val_loss: 2.2728e-04 - val_mean_absolute_error: 0.0125
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1791e-04 - mean_absolute_error: 0.0080 - val_loss: 2.3816e-04 - val_mean_absolute_error: 0.0129
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2248e-04 - mean_absolute_error: 0.0082 - val_loss: 2.4922e-04 - val_mean_absolute_error: 0.0133
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2712e-04 - mean_absolute_error: 0.0084 - val_loss: 2.5998e-04 - val_mean_absolute_error: 0.0136
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3159e-04 - mean_absolute_error: 0.0086 - val_loss: 2.6989e-04 - val_mean_absolute_error: 0.0139
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3563e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7837e-04 - val_mean_absolute_error: 0.0142
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3897e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8495e-04 - val_mean_absolute_error: 0.0144
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4142e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8934e-04 - val_mean_absolute_error: 0.0145
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4289e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9156e-04 - val_mean_absolute_error: 0.0146
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4342e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9192e-04 - val_mean_absolute_error: 0.0146
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4320e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9093e-04 - val_mean_absolute_error: 0.0145
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4246e-04 - mean_absolute_error: 0.0091 - val_loss: 2.8919e-04 - val_mean_absolute_error: 0.0145
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4147e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8722e-04 - val_mean_absolute_error: 0.0144
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4044e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8540e-04 - val_mean_absolute_error: 0.0144
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3950e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8392e-04 - val_mean_absolute_error: 0.0143
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3873e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8284e-04 - val_mean_absolute_error: 0.0143
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3812e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8208e-04 - val_mean_absolute_error: 0.0143
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3764e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8152e-04 - val_mean_absolute_error: 0.0142
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3723e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8104e-04 - val_mean_absolute_error: 0.0142
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3683e-04 - mean_absolute_error: 0.0088 - val_loss: 2.8052e-04 - val_mean_absolute_error: 0.0142
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3640e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7990e-04 - val_mean_absolute_error: 0.0142
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3592e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7916e-04 - val_mean_absolute_error: 0.0142
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3539e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7829e-04 - val_mean_absolute_error: 0.0141
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3481e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7734e-04 - val_mean_absolute_error: 0.0141

# %% [markdown]
# Visualizing training

# %%
# Visualize GRU training performance

plot_training_curves(
    gru_history,
    "Baseline GRU"
)

# %% [markdown]
# The model certainly overfit now! The validation loss and MAE started to increase

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate GRU on held-out future test data

evaluate_and_plot(
    gru_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline GRU"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Baseline GRU Train RMSE: 560.80
# Baseline GRU Test RMSE: 4732.63
# Baseline GRU Train MAE: 438.16
# Baseline GRU Test MAE: 3248.33

# %% [markdown]
# ### Activity: Improving Forecasting Models
#
# Improve each of the baseline three recurrent models (SimpleRNN, LSTM, and GRU) and compare their forecasting performance against the XGBoost models shown below. You should provide the code for each improved model and include a markdown cell after each model describing what you changed, what you explored, and how the changes affected performance. After completing your experiments, provide a short overall summary discussing which approaches appeared most effective, which models were easiest or hardest to tune, and what tradeoffs you observed between model complexity, training stability, and forecasting performance.

# %% [markdown]
# ### Simple RNN experiment: Increase size of the recurrent layer

# %%
# SimpleRNN model with larger recurrent layer

rnn_model_experiment1 = Sequential([
    SimpleRNN(
        16,                                     # larger recurrent layer
        activation="tanh",                     # standard activation for SimpleRNN
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

rnn_model_experiment1.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

rnn_history_experiment1 = rnn_model_experiment1.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0463 - mean_absolute_error: 0.1663 - val_loss: 0.0167 - val_mean_absolute_error: 0.0882
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0083 - mean_absolute_error: 0.0736 - val_loss: 0.0118 - val_mean_absolute_error: 0.0755
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0041 - mean_absolute_error: 0.0495 - val_loss: 0.0086 - val_mean_absolute_error: 0.0605
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0030 - mean_absolute_error: 0.0413 - val_loss: 0.0076 - val_mean_absolute_error: 0.0566
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0027 - mean_absolute_error: 0.0394 - val_loss: 0.0071 - val_mean_absolute_error: 0.0557
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0025 - mean_absolute_error: 0.0380 - val_loss: 0.0065 - val_mean_absolute_error: 0.0537
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023 - mean_absolute_error: 0.0361 - val_loss: 0.0058 - val_mean_absolute_error: 0.0513
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0341 - val_loss: 0.0052 - val_mean_absolute_error: 0.0486
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0322 - val_loss: 0.0046 - val_mean_absolute_error: 0.0459
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 0.0041 - val_mean_absolute_error: 0.0433
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - val_loss: 0.0036 - val_mean_absolute_error: 0.0407
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - mean_absolute_error: 0.0270 - val_loss: 0.0032 - val_mean_absolute_error: 0.0382
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0255 - val_loss: 0.0028 - val_mean_absolute_error: 0.0359
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010 - mean_absolute_error: 0.0241 - val_loss: 0.0025 - val_mean_absolute_error: 0.0337
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2578e-04 - mean_absolute_error: 0.0228 - val_loss: 0.0022 - val_mean_absolute_error: 0.0316
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3359e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0020 - val_mean_absolute_error: 0.0296
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.5165e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0018 - val_mean_absolute_error: 0.0277
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7864e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0016 - val_mean_absolute_error: 0.0260
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1349e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0014 - val_mean_absolute_error: 0.0244
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5537e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0012 - val_mean_absolute_error: 0.0229
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0364e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0011 - val_mean_absolute_error: 0.0215
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5779e-04 - mean_absolute_error: 0.0160 - val_loss: 9.9339e-04 - val_mean_absolute_error: 0.0203
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 4.1740e-04 - mean_absolute_error: 0.0153 - val_loss: 8.9914e-04 - val_mean_absolute_error: 0.0193
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 3.8210e-04 - mean_absolute_error: 0.0147 - val_loss: 8.1966e-04 - val_mean_absolute_error: 0.0184
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5151e-04 - mean_absolute_error: 0.0141 - val_loss: 7.5286e-04 - val_mean_absolute_error: 0.0177
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 3.2520e-04 - mean_absolute_error: 0.0136 - val_loss: 6.9668e-04 - val_mean_absolute_error: 0.0172
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 3.0273e-04 - mean_absolute_error: 0.0131 - val_loss: 6.4912e-04 - val_mean_absolute_error: 0.0168
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 2.8357e-04 - mean_absolute_error: 0.0127 - val_loss: 6.0844e-04 - val_mean_absolute_error: 0.0165
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 2.6723e-04 - mean_absolute_error: 0.0124 - val_loss: 5.7317e-04 - val_mean_absolute_error: 0.0161
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5321e-04 - mean_absolute_error: 0.0120 - val_loss: 5.4220e-04 - val_mean_absolute_error: 0.0158
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4108e-04 - mean_absolute_error: 0.0117 - val_loss: 5.1470e-04 - val_mean_absolute_error: 0.0155
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 2.3048e-04 - mean_absolute_error: 0.0115 - val_loss: 4.9006e-04 - val_mean_absolute_error: 0.0153
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 2.2113e-04 - mean_absolute_error: 0.0112 - val_loss: 4.6785e-04 - val_mean_absolute_error: 0.0150
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1280e-04 - mean_absolute_error: 0.0110 - val_loss: 4.4777e-04 - val_mean_absolute_error: 0.0148
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 2.0531e-04 - mean_absolute_error: 0.0108 - val_loss: 4.2958e-04 - val_mean_absolute_error: 0.0146
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 1.9856e-04 - mean_absolute_error: 0.0106 - val_loss: 4.1309e-04 - val_mean_absolute_error: 0.0144
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 1.9243e-04 - mean_absolute_error: 0.0104 - val_loss: 3.9817e-04 - val_mean_absolute_error: 0.0143
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 1.8686e-04 - mean_absolute_error: 0.0103 - val_loss: 3.8469e-04 - val_mean_absolute_error: 0.0141
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8178e-04 - mean_absolute_error: 0.0101 - val_loss: 3.7255e-04 - val_mean_absolute_error: 0.0140
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7715e-04 - mean_absolute_error: 0.0100 - val_loss: 3.6165e-04 - val_mean_absolute_error: 0.0139
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7294e-04 - mean_absolute_error: 0.0098 - val_loss: 3.5191e-04 - val_mean_absolute_error: 0.0138
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 1.6911e-04 - mean_absolute_error: 0.0097 - val_loss: 3.4324e-04 - val_mean_absolute_error: 0.0137
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6562e-04 - mean_absolute_error: 0.0096 - val_loss: 3.3556e-04 - val_mean_absolute_error: 0.0136
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 1.6246e-04 - mean_absolute_error: 0.0095 - val_loss: 3.2878e-04 - val_mean_absolute_error: 0.0136
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5958e-04 - mean_absolute_error: 0.0094 - val_loss: 3.2282e-04 - val_mean_absolute_error: 0.0136
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5696e-04 - mean_absolute_error: 0.0093 - val_loss: 3.1759e-04 - val_mean_absolute_error: 0.0135
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5458e-04 - mean_absolute_error: 0.0093 - val_loss: 3.1300e-04 - val_mean_absolute_error: 0.0135
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5240e-04 - mean_absolute_error: 0.0092 - val_loss: 3.0896e-04 - val_mean_absolute_error: 0.0135
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5040e-04 - mean_absolute_error: 0.0091 - val_loss: 3.0540e-04 - val_mean_absolute_error: 0.0136
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4855e-04 - mean_absolute_error: 0.0091 - val_loss: 3.0223e-04 - val_mean_absolute_error: 0.0136

# %% [markdown]
# Visualizing training

# %%
# Visualize SimpleRNN with larger recurrent layer training performance

plot_training_curves(
    rnn_history_experiment1,
    "SimpleRNN with larger RL"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate SimpleRNN with larger RL on held-out future test data

evaluate_and_plot(
    rnn_model_experiment1,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "SimpleRNN with larger RL"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# SimpleRNN with larger RL Train RMSE: 597.98
# SimpleRNN with larger RL Test RMSE: 6350.68
# SimpleRNN with larger RL Train MAE: 436.65
# SimpleRNN with larger RL Test MAE: 3966.43

# %% [markdown]
# Changed: Recurrent layer size from 8 to 16.
#
# Explored: Architecture change. How does increasing the model's capacity impact performance?
#
# Impact on performance: Interestingly, the training and validation loss/MAE curves looked better than the baseline model (the curves were closer together) but a larger gap formed between the actual and predicted bitcoin close price. Neither the test RMSE nor the test MAE improved from the baseline model.

# %% [markdown]
# ### Simple RNN experiment: Increase size of the recurrent layer with regularization

# %%
# SimpleRNN model with larger recurrent layer and dropout

rnn_model_experiment2 = Sequential([
    SimpleRNN(
        16,                                     # larger recurrent layer
        activation="tanh",                     # standard activation for SimpleRNN
        dropout=0.1,
        recurrent_dropout=0.1,
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

rnn_model_experiment2.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

rnn_history_experiment2 = rnn_model_experiment2.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0250 - mean_absolute_error: 0.1157 - val_loss: 0.0050 - val_mean_absolute_error: 0.0403
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0099 - mean_absolute_error: 0.0751 - val_loss: 0.0032 - val_mean_absolute_error: 0.0327
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0582 - val_loss: 0.0026 - val_mean_absolute_error: 0.0348
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0048 - mean_absolute_error: 0.0529 - val_loss: 0.0030 - val_mean_absolute_error: 0.0453
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0040 - mean_absolute_error: 0.0474 - val_loss: 0.0016 - val_mean_absolute_error: 0.0279
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0032 - mean_absolute_error: 0.0413 - val_loss: 0.0012 - val_mean_absolute_error: 0.0223
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0025 - mean_absolute_error: 0.0370 - val_loss: 0.0015 - val_mean_absolute_error: 0.0307
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023 - mean_absolute_error: 0.0346 - val_loss: 0.0010 - val_mean_absolute_error: 0.0235
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0321 - val_loss: 7.9900e-04 - val_mean_absolute_error: 0.0198
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0327 - val_loss: 8.6069e-04 - val_mean_absolute_error: 0.0227
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0292 - val_loss: 9.6456e-04 - val_mean_absolute_error: 0.0259
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0300 - val_loss: 7.2413e-04 - val_mean_absolute_error: 0.0214
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0295 - val_loss: 9.7209e-04 - val_mean_absolute_error: 0.0267
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0285 - val_loss: 0.0011 - val_mean_absolute_error: 0.0285
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - mean_absolute_error: 0.0266 - val_loss: 5.9806e-04 - val_mean_absolute_error: 0.0192
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010 - mean_absolute_error: 0.0241 - val_loss: 5.2864e-04 - val_mean_absolute_error: 0.0180
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0243 - val_loss: 7.8673e-04 - val_mean_absolute_error: 0.0241
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - mean_absolute_error: 0.0250 - val_loss: 5.9019e-04 - val_mean_absolute_error: 0.0198
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0239 - val_loss: 6.0829e-04 - val_mean_absolute_error: 0.0204
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0237 - val_loss: 6.0976e-04 - val_mean_absolute_error: 0.0207
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.9676e-04 - mean_absolute_error: 0.0223 - val_loss: 6.1513e-04 - val_mean_absolute_error: 0.0207
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1888e-04 - mean_absolute_error: 0.0227 - val_loss: 5.1363e-04 - val_mean_absolute_error: 0.0183
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.4727e-04 - mean_absolute_error: 0.0223 - val_loss: 6.8519e-04 - val_mean_absolute_error: 0.0226
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010 - mean_absolute_error: 0.0224 - val_loss: 6.4723e-04 - val_mean_absolute_error: 0.0217
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.7083e-04 - mean_absolute_error: 0.0220 - val_loss: 6.3256e-04 - val_mean_absolute_error: 0.0213
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1963e-04 - mean_absolute_error: 0.0218 - val_loss: 5.0696e-04 - val_mean_absolute_error: 0.0184
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.5473e-04 - mean_absolute_error: 0.0214 - val_loss: 6.4272e-04 - val_mean_absolute_error: 0.0215
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9222e-04 - mean_absolute_error: 0.0216 - val_loss: 7.2901e-04 - val_mean_absolute_error: 0.0234
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5540e-04 - mean_absolute_error: 0.0221 - val_loss: 7.5663e-04 - val_mean_absolute_error: 0.0243
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5384e-04 - mean_absolute_error: 0.0209 - val_loss: 3.9252e-04 - val_mean_absolute_error: 0.0159
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.2299e-04 - mean_absolute_error: 0.0198 - val_loss: 6.2113e-04 - val_mean_absolute_error: 0.0211
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6293e-04 - mean_absolute_error: 0.0212 - val_loss: 4.2358e-04 - val_mean_absolute_error: 0.0169
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.2759e-04 - mean_absolute_error: 0.0178 - val_loss: 3.5690e-04 - val_mean_absolute_error: 0.0148
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6563e-04 - mean_absolute_error: 0.0197 - val_loss: 4.8666e-04 - val_mean_absolute_error: 0.0184
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1604e-04 - mean_absolute_error: 0.0206 - val_loss: 7.8704e-04 - val_mean_absolute_error: 0.0247
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.5754e-04 - mean_absolute_error: 0.0223 - val_loss: 7.7585e-04 - val_mean_absolute_error: 0.0248
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0137e-04 - mean_absolute_error: 0.0190 - val_loss: 5.1535e-04 - val_mean_absolute_error: 0.0190
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.5070e-04 - mean_absolute_error: 0.0186 - val_loss: 3.4238e-04 - val_mean_absolute_error: 0.0145
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5151e-04 - mean_absolute_error: 0.0170 - val_loss: 2.9632e-04 - val_mean_absolute_error: 0.0131
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8829e-04 - mean_absolute_error: 0.0195 - val_loss: 4.5674e-04 - val_mean_absolute_error: 0.0179
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.5398e-04 - mean_absolute_error: 0.0195 - val_loss: 4.6342e-04 - val_mean_absolute_error: 0.0181
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2581e-04 - mean_absolute_error: 0.0194 - val_loss: 7.3771e-04 - val_mean_absolute_error: 0.0244
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.1917e-04 - mean_absolute_error: 0.0199 - val_loss: 5.6887e-04 - val_mean_absolute_error: 0.0201
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8592e-04 - mean_absolute_error: 0.0200 - val_loss: 5.6952e-04 - val_mean_absolute_error: 0.0207
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6790e-04 - mean_absolute_error: 0.0201 - val_loss: 6.6877e-04 - val_mean_absolute_error: 0.0230
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6069e-04 - mean_absolute_error: 0.0191 - val_loss: 5.3018e-04 - val_mean_absolute_error: 0.0200
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9016e-04 - mean_absolute_error: 0.0201 - val_loss: 6.0123e-04 - val_mean_absolute_error: 0.0216
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0639e-04 - mean_absolute_error: 0.0195 - val_loss: 7.3162e-04 - val_mean_absolute_error: 0.0244
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4541e-04 - mean_absolute_error: 0.0197 - val_loss: 8.2956e-04 - val_mean_absolute_error: 0.0262
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6949e-04 - mean_absolute_error: 0.0193 - val_loss: 4.8642e-04 - val_mean_absolute_error: 0.0186

# %% [markdown]
# Visualizing training

# %%
# Visualize SimpleRNN with larger recurrent layer training performance

plot_training_curves(
    rnn_history_experiment2,
    "SimpleRNN with larger RL and dropout"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate SimpleRNN with larger RL on held-out future test data

evaluate_and_plot(
    rnn_model_experiment2,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "SimpleRNN with larger RL and dropout"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# SimpleRNN with larger RL and dropout Train RMSE: 686.33
# SimpleRNN with larger RL and dropout Test RMSE: 2301.54
# SimpleRNN with larger RL and dropout Train MAE: 607.12
# SimpleRNN with larger RL and dropout Test MAE: 1333.80

# %% [markdown]
# Changed: Recurrent layer size from 8 to 16 and adding both dropout and recurrent dropout (regularization).
#
# Explored: Architecture change and the addition of regularization. How does increasing the model's capacity impact performance? Does adding regularization control for this change?
#
# Impact on performance: This time, the RNN model performed better than the baseline (test smallest RMSE and MAE of 2301.54 and 1333.80, respectively). Although the validation curves were noisier, they matched the training curves much closer than both the baseline model and the previous experiment.

# %% [markdown]
# ### LSTM experiment: Reduce lookback

# %%
# Create train/test recurrent tensors with new look back

train_size = int(len(scaled_features) * 0.8)                    # chronological 80/20 split

train_bitcoin = scaled_features[:train_size]                    # earlier data
test_bitcoin = scaled_features[train_size:]                     # held-out future data

trainX_bitcoin, trainY_bitcoin = create_sequences(
    train_bitcoin,
    target_index,
    look_back = 5
)

testX_bitcoin, testY_bitcoin = create_sequences(
    test_bitcoin,
    target_index,
    look_back = 5
)

print("trainX_bitcoin shape:", trainX_bitcoin.shape)
print("testX_bitcoin shape:", testX_bitcoin.shape)
print("trainY_bitcoin shape:", trainY_bitcoin.shape)
print("testY_bitcoin shape:", testY_bitcoin.shape)
# Out:
# trainX_bitcoin shape: (795, 5, 5)
# testX_bitcoin shape: (195, 5, 5)
# trainY_bitcoin shape: (795,)
# testY_bitcoin shape: (195,)

# %%
# Build and train LSTM model with reduced lookback
lstm_model_experiment1 = Sequential([
    LSTM(
        8,                                     # small baseline LSTM layer
        activation="tanh",                     # standard LSTM hidden-state activation
        input_shape=(5, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

lstm_model_experiment1.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

lstm_history_experiment1 = lstm_model_experiment1.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0026 - mean_absolute_error: 0.0409 - val_loss: 3.2294e-04 - val_mean_absolute_error: 0.0134
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - mean_absolute_error: 0.0331 - val_loss: 2.8312e-04 - val_mean_absolute_error: 0.0128
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9830e-04 - mean_absolute_error: 0.0233 - val_loss: 2.1647e-04 - val_mean_absolute_error: 0.0097
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7665e-04 - mean_absolute_error: 0.0178 - val_loss: 2.1993e-04 - val_mean_absolute_error: 0.0101
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8238e-04 - mean_absolute_error: 0.0130 - val_loss: 2.2731e-04 - val_mean_absolute_error: 0.0105
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9826e-04 - mean_absolute_error: 0.0101 - val_loss: 2.2430e-04 - val_mean_absolute_error: 0.0105
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7062e-04 - mean_absolute_error: 0.0091 - val_loss: 2.1973e-04 - val_mean_absolute_error: 0.0103
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6271e-04 - mean_absolute_error: 0.0089 - val_loss: 2.1631e-04 - val_mean_absolute_error: 0.0101
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6099e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1466e-04 - val_mean_absolute_error: 0.0100
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6111e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1470e-04 - val_mean_absolute_error: 0.0099
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6155e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1576e-04 - val_mean_absolute_error: 0.0098
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6197e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1742e-04 - val_mean_absolute_error: 0.0098
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6237e-04 - mean_absolute_error: 0.0089 - val_loss: 2.1942e-04 - val_mean_absolute_error: 0.0098
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6277e-04 - mean_absolute_error: 0.0089 - val_loss: 2.2158e-04 - val_mean_absolute_error: 0.0097
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6316e-04 - mean_absolute_error: 0.0089 - val_loss: 2.2375e-04 - val_mean_absolute_error: 0.0097
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6353e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2581e-04 - val_mean_absolute_error: 0.0097
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6388e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2768e-04 - val_mean_absolute_error: 0.0097
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6418e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2931e-04 - val_mean_absolute_error: 0.0097
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6443e-04 - mean_absolute_error: 0.0091 - val_loss: 2.3068e-04 - val_mean_absolute_error: 0.0097
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6461e-04 - mean_absolute_error: 0.0091 - val_loss: 2.3176e-04 - val_mean_absolute_error: 0.0097
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6473e-04 - mean_absolute_error: 0.0091 - val_loss: 2.3257e-04 - val_mean_absolute_error: 0.0096
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6479e-04 - mean_absolute_error: 0.0091 - val_loss: 2.3312e-04 - val_mean_absolute_error: 0.0096
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6477e-04 - mean_absolute_error: 0.0091 - val_loss: 2.3343e-04 - val_mean_absolute_error: 0.0096
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6468e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3353e-04 - val_mean_absolute_error: 0.0096
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6452e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3343e-04 - val_mean_absolute_error: 0.0095
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6429e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3316e-04 - val_mean_absolute_error: 0.0095
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6401e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3274e-04 - val_mean_absolute_error: 0.0095
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6366e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3220e-04 - val_mean_absolute_error: 0.0095
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6326e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3155e-04 - val_mean_absolute_error: 0.0094
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6281e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3081e-04 - val_mean_absolute_error: 0.0094
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6232e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2999e-04 - val_mean_absolute_error: 0.0094
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6178e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2912e-04 - val_mean_absolute_error: 0.0094
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6121e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2819e-04 - val_mean_absolute_error: 0.0093
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6061e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2723e-04 - val_mean_absolute_error: 0.0093
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5998e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2623e-04 - val_mean_absolute_error: 0.0093
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5933e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2520e-04 - val_mean_absolute_error: 0.0093
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5866e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2416e-04 - val_mean_absolute_error: 0.0092
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5798e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2310e-04 - val_mean_absolute_error: 0.0092
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5728e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2203e-04 - val_mean_absolute_error: 0.0092
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5657e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2095e-04 - val_mean_absolute_error: 0.0092
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5585e-04 - mean_absolute_error: 0.0090 - val_loss: 2.1987e-04 - val_mean_absolute_error: 0.0091
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5512e-04 - mean_absolute_error: 0.0090 - val_loss: 2.1878e-04 - val_mean_absolute_error: 0.0091
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5439e-04 - mean_absolute_error: 0.0089 - val_loss: 2.1769e-04 - val_mean_absolute_error: 0.0091
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5366e-04 - mean_absolute_error: 0.0089 - val_loss: 2.1660e-04 - val_mean_absolute_error: 0.0090
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5293e-04 - mean_absolute_error: 0.0089 - val_loss: 2.1551e-04 - val_mean_absolute_error: 0.0090
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5219e-04 - mean_absolute_error: 0.0089 - val_loss: 2.1442e-04 - val_mean_absolute_error: 0.0090
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5146e-04 - mean_absolute_error: 0.0089 - val_loss: 2.1333e-04 - val_mean_absolute_error: 0.0090
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5073e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1225e-04 - val_mean_absolute_error: 0.0089
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5000e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1117e-04 - val_mean_absolute_error: 0.0089
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4927e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1009e-04 - val_mean_absolute_error: 0.0089

# %% [markdown]
# Visualizing training

# %%
# Visualize LSTM training performance

plot_training_curves(
    lstm_history_experiment1,
    "LSTM with reduced look back"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate LSTM on held-out future test data

evaluate_and_plot(
    lstm_model_experiment1,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "LSTM with reduced look back"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# LSTM with reduced look back Train RMSE: 457.82
# LSTM with reduced look back Test RMSE: 2648.33
# LSTM with reduced look back Train MAE: 325.90
# LSTM with reduced look back Test MAE: 1486.84

# %% [markdown]
# Changed: Lookback window from 10 to 5 to capture more noise in the data.
#
# Explored: Preprocessing change. How does changing the shape of the input data impact model performance?
#
# Impact on performance: More noise in the time series data was captured with a smaller lookback compared to the baseline LSTM model. However, this experiment did not improve model performance compared to the baseline. It appears that a larger gap was formed between the actual and predicted bitcoin close price near the end of the test time index.

# %% [markdown]
# ### LSTM experiment: Reduce lookback

# %%
# Create train/test recurrent tensors with new look back

train_size = int(len(scaled_features) * 0.8)                    # chronological 80/20 split

train_bitcoin = scaled_features[:train_size]                    # earlier data
test_bitcoin = scaled_features[train_size:]                     # held-out future data

trainX_bitcoin, trainY_bitcoin = create_sequences(
    train_bitcoin,
    target_index,
    look_back = 2
)

testX_bitcoin, testY_bitcoin = create_sequences(
    test_bitcoin,
    target_index,
    look_back = 2
)

print("trainX_bitcoin shape:", trainX_bitcoin.shape)
print("testX_bitcoin shape:", testX_bitcoin.shape)
print("trainY_bitcoin shape:", trainY_bitcoin.shape)
print("testY_bitcoin shape:", testY_bitcoin.shape)
# Out:
# trainX_bitcoin shape: (798, 2, 5)
# testX_bitcoin shape: (198, 2, 5)
# trainY_bitcoin shape: (798,)
# testY_bitcoin shape: (198,)

# %%
# Build and train LSTM model with reduced lookback
lstm_model_experiment2 = Sequential([
    LSTM(
        8,                                     # small baseline LSTM layer
        activation="tanh",                     # standard LSTM hidden-state activation
        input_shape=(2, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

lstm_model_experiment2.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

lstm_history_experiment2 = lstm_model_experiment2.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0072 - mean_absolute_error: 0.0708 - val_loss: 0.0029 - val_mean_absolute_error: 0.0481
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 0.0026 - mean_absolute_error: 0.0408 - val_loss: 0.0011 - val_mean_absolute_error: 0.0292
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 0.0023 - mean_absolute_error: 0.0400 - val_loss: 9.3284e-04 - val_mean_absolute_error: 0.0268
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0354 - val_loss: 7.3997e-04 - val_mean_absolute_error: 0.0233
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - mean_absolute_error: 0.0313 - val_loss: 5.9277e-04 - val_mean_absolute_error: 0.0201
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0272 - val_loss: 4.8295e-04 - val_mean_absolute_error: 0.0172
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9663e-04 - mean_absolute_error: 0.0231 - val_loss: 4.0351e-04 - val_mean_absolute_error: 0.0148
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 5.5706e-04 - mean_absolute_error: 0.0192 - val_loss: 3.4717e-04 - val_mean_absolute_error: 0.0129
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - loss: 3.7696e-04 - mean_absolute_error: 0.0157 - val_loss: 3.0628e-04 - val_mean_absolute_error: 0.0116
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 2.5237e-04 - mean_absolute_error: 0.0127 - val_loss: 2.7439e-04 - val_mean_absolute_error: 0.0106
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 1.7460e-04 - mean_absolute_error: 0.0103 - val_loss: 2.4766e-04 - val_mean_absolute_error: 0.0099
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 1.3153e-04 - mean_absolute_error: 0.0086 - val_loss: 2.2487e-04 - val_mean_absolute_error: 0.0093
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 1.1057e-04 - mean_absolute_error: 0.0077 - val_loss: 2.0613e-04 - val_mean_absolute_error: 0.0090
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 1.0148e-04 - mean_absolute_error: 0.0071 - val_loss: 1.9143e-04 - val_mean_absolute_error: 0.0087
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 9.7721e-05 - mean_absolute_error: 0.0069 - val_loss: 1.8025e-04 - val_mean_absolute_error: 0.0085
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 9.5960e-05 - mean_absolute_error: 0.0068 - val_loss: 1.7176e-04 - val_mean_absolute_error: 0.0084
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 9.4849e-05 - mean_absolute_error: 0.0067 - val_loss: 1.6526e-04 - val_mean_absolute_error: 0.0082
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 9.3955e-05 - mean_absolute_error: 0.0066 - val_loss: 1.6020e-04 - val_mean_absolute_error: 0.0081
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - loss: 9.3173e-05 - mean_absolute_error: 0.0066 - val_loss: 1.5625e-04 - val_mean_absolute_error: 0.0080
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - loss: 9.2484e-05 - mean_absolute_error: 0.0065 - val_loss: 1.5315e-04 - val_mean_absolute_error: 0.0079
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1880e-05 - mean_absolute_error: 0.0065 - val_loss: 1.5073e-04 - val_mean_absolute_error: 0.0079
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1351e-05 - mean_absolute_error: 0.0065 - val_loss: 1.4884e-04 - val_mean_absolute_error: 0.0078
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 9.0887e-05 - mean_absolute_error: 0.0065 - val_loss: 1.4736e-04 - val_mean_absolute_error: 0.0078
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.0475e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4620e-04 - val_mean_absolute_error: 0.0078
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.0105e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4528e-04 - val_mean_absolute_error: 0.0078
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 8.9768e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4453e-04 - val_mean_absolute_error: 0.0078
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9458e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4390e-04 - val_mean_absolute_error: 0.0077
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9168e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4337e-04 - val_mean_absolute_error: 0.0077
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.8895e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4291e-04 - val_mean_absolute_error: 0.0077
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 8.8636e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4249e-04 - val_mean_absolute_error: 0.0077
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 8.8389e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4211e-04 - val_mean_absolute_error: 0.0077
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8153e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4176e-04 - val_mean_absolute_error: 0.0077
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 8.7928e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4144e-04 - val_mean_absolute_error: 0.0076
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 8.7716e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4115e-04 - val_mean_absolute_error: 0.0076
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - loss: 8.7518e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4088e-04 - val_mean_absolute_error: 0.0076
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - loss: 8.7334e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4066e-04 - val_mean_absolute_error: 0.0076
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - loss: 8.7168e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4046e-04 - val_mean_absolute_error: 0.0075
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - loss: 8.7021e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4031e-04 - val_mean_absolute_error: 0.0075
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 8.6895e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4019e-04 - val_mean_absolute_error: 0.0075
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 8.6794e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4011e-04 - val_mean_absolute_error: 0.0075
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6718e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4007e-04 - val_mean_absolute_error: 0.0075
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6670e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4005e-04 - val_mean_absolute_error: 0.0074
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6652e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4007e-04 - val_mean_absolute_error: 0.0074
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 8.6663e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4011e-04 - val_mean_absolute_error: 0.0074
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 8.6704e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4017e-04 - val_mean_absolute_error: 0.0074
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 8.6775e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4024e-04 - val_mean_absolute_error: 0.0074
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 8.6875e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4031e-04 - val_mean_absolute_error: 0.0074
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 8.7001e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4037e-04 - val_mean_absolute_error: 0.0074
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 8.7151e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4043e-04 - val_mean_absolute_error: 0.0074
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 8.7321e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4046e-04 - val_mean_absolute_error: 0.0074

# %% [markdown]
# Visualizing training

# %%
# Visualize LSTM training performance

plot_training_curves(
    lstm_history_experiment2,
    "LSTM with reduced look back"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate LSTM on held-out future test data

evaluate_and_plot(
    lstm_model_experiment2,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "LSTM with reduced look back"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# LSTM with reduced look back Train RMSE: 365.75
# LSTM with reduced look back Test RMSE: 1033.05
# LSTM with reduced look back Train MAE: 245.83
# LSTM with reduced look back Test MAE: 575.68

# %% [markdown]
# Changed: Lookback window from 10 to 2 to capture more noise in the data.
#
# Explored: Preprocessing change. How does changing the shape of the input data (even more) impact model performance?
#
# Impact on performance: Much more noise in the time series data was captured with a smaller lookback compared to the baseline LSTM model and my previous LSTM experiment. This experiment improved model performance substantially. The actual and predicted bitcoin closing prices are near-identical and the test RMSE and MAE are the smallest (1033.05 and 575.68, respectively) out of all my experiments so far. This model performs very close to the XGBoost model using return based predictions.

# %% [markdown]
# ### GRU experiment: early stopping

# %%
# Your GRU code
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True  # rolls back to best epoch automatically
)

gru_model_experiment1 = Sequential([
    GRU(
        8,
        activation="tanh",
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),
    Dense(1)
])

gru_model_experiment1.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

gru_history_experiment1 = gru_model_experiment1.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0032 - mean_absolute_error: 0.0453 - val_loss: 6.8948e-04 - val_mean_absolute_error: 0.0182
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.0022 - mean_absolute_error: 0.0394 - val_loss: 8.9268e-04 - val_mean_absolute_error: 0.0201
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 0.0012 - mean_absolute_error: 0.0283 - val_loss: 8.7841e-04 - val_mean_absolute_error: 0.0195
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 6.2569e-04 - mean_absolute_error: 0.0200 - val_loss: 8.1858e-04 - val_mean_absolute_error: 0.0191
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 3.9599e-04 - mean_absolute_error: 0.0154 - val_loss: 7.3770e-04 - val_mean_absolute_error: 0.0183
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 2.8631e-04 - mean_absolute_error: 0.0126 - val_loss: 6.2987e-04 - val_mean_absolute_error: 0.0170
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 2.3022e-04 - mean_absolute_error: 0.0112 - val_loss: 5.1293e-04 - val_mean_absolute_error: 0.0154
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9777e-04 - mean_absolute_error: 0.0102 - val_loss: 4.0605e-04 - val_mean_absolute_error: 0.0138
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7677e-04 - mean_absolute_error: 0.0096 - val_loss: 3.1989e-04 - val_mean_absolute_error: 0.0123
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6193e-04 - mean_absolute_error: 0.0091 - val_loss: 2.5630e-04 - val_mean_absolute_error: 0.0111
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5082e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1238e-04 - val_mean_absolute_error: 0.0100
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4227e-04 - mean_absolute_error: 0.0084 - val_loss: 1.8391e-04 - val_mean_absolute_error: 0.0093
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3567e-04 - mean_absolute_error: 0.0081 - val_loss: 1.6688e-04 - val_mean_absolute_error: 0.0088
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3057e-04 - mean_absolute_error: 0.0079 - val_loss: 1.5788e-04 - val_mean_absolute_error: 0.0084
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2662e-04 - mean_absolute_error: 0.0078 - val_loss: 1.5419e-04 - val_mean_absolute_error: 0.0083
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2351e-04 - mean_absolute_error: 0.0077 - val_loss: 1.5375e-04 - val_mean_absolute_error: 0.0081
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2104e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5506e-04 - val_mean_absolute_error: 0.0081
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1901e-04 - mean_absolute_error: 0.0075 - val_loss: 1.5710e-04 - val_mean_absolute_error: 0.0081
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1730e-04 - mean_absolute_error: 0.0075 - val_loss: 1.5923e-04 - val_mean_absolute_error: 0.0081
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1582e-04 - mean_absolute_error: 0.0075 - val_loss: 1.6110e-04 - val_mean_absolute_error: 0.0081
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 1.1451e-04 - mean_absolute_error: 0.0074 - val_loss: 1.6253e-04 - val_mean_absolute_error: 0.0081

# %% [markdown]
# Visualizing training

# %%
# Visualize GRU training performance

plot_training_curves(
    gru_history_experiment1,
    "GRU with early stopping"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate GRU on held-out future test data

evaluate_and_plot(
    gru_model_experiment1,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "GRU with early stopping"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# GRU with early stopping Train RMSE: 430.33
# GRU with early stopping Test RMSE: 1762.52
# GRU with early stopping Train MAE: 330.24
# GRU with early stopping Test MAE: 975.65

# %% [markdown]
# Changed: Added early stopping.
#
# Explored: Adding regularization (early stopping) to prevent overfitting of the GRU model.
#
# Impact on performance: Adding early stopping reduced model overfitting by a great deal. Neither the validation loss nor the validation MAE increased after ten epochs like the baseline model. In fact, early stopping made the model stop training after 20 epochs instead of continuing with all 50. This experiment also resulted in my best GRU model performance. The actual and predicted bitcoin close prices are much closer now and test RMSE and MAE have reduced substantially (1762.52 and 975.65, respectively).

# %% [markdown]
# ### Your summary

# %% [markdown]
# **Most effective approaches**
#
# The most effective approaches for each model was combining a larger recurrent layer with dropout for the SimpleRNN, reducing the lookback window from 10 to 2 for the LSTM, and adding early stopping to the GRU training process. Each of these three methods resulted in models that performed better than their respective baselines with regards to test RMSE and test MAE. However, none of the tuned models resulted in better performance than the XGBoost model using return based predictions
#
# **Models easiest vs. hardest to tune**
#
# The LSTM and GRU models were easiest to tune. The GRU especially, as it resulted in substantially better bitcoin close price predictions by just addressing the baseline model overfitting with early stopping. Similarly, the LSTM model required only a quick change of reducing the lookback window enough to capture noise in the data. The SimpleRNN model required the most tuning (both an architecture change and the addition of regularization) to see an improvement in model performance from the baseline.
#
# **Tradeoffs**
#
# Interestingly, increasing model capacity (i.e. the larger recurrent layer in the first SimpleRNN experiment model) did not improve forecasting performance. In fact, this model performed worse until regularization was added. Although the addition of regularization to model capacity improved the SimpleRNN model performance, the model became much less stable, as seen in the noisiness of the valdiation loss and MAE curves. Overall, it seems like decreasing model complexity (reducing the look back window, adding regularization like dropout and early stopping) led to improved models from their baselines.

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ### Do you need RNN for time series data?
#
# #### XGB with lagged features

# %% [markdown]
# Plotting function for nonscaled models

# %%
# Generic prediction plotting function for models already on the original scale

def plot_predictions(actual, predicted, title):

    plt.figure(figsize=(10, 4))

    plt.plot(actual, label="Actual")
    plt.plot(predicted, label="Predicted")

    plt.title(title)
    plt.xlabel("Test time index")
    plt.ylabel("Bitcoin Close Price (USD)")

    plt.ticklabel_format(style="plain", axis="y")

    plt.legend()
    plt.show()

# %% [markdown]
# XGB Data preparation

# %%
# Create lagged features for XGBoost

xgb_data = bitcoin[["date"] + features].copy()

lag_days = 10

for lag in range(1, lag_days + 1):
    for col in features:
        xgb_data[f"{col}_lag{lag}"] = xgb_data[col].shift(lag)

xgb_data["target_close_USD"] = xgb_data["close_USD"]

xgb_data = xgb_data.dropna().reset_index(drop=True)

xgb_data.head()
# Out:
#         date  open_USD  \
# 0 2018-05-17   8330.00
# 1 2018-05-18   8038.82
# 2 2018-05-19   8238.01
# 3 2018-05-20   8233.49
# 4 2018-05-21   8526.97
#
#    high_USD  low_USD  \
# 0   8464.00  7979.00
# 1   8273.21  7911.90
# 2   8390.80  8095.73
# 3   8609.00  8163.90
# 4   8595.31  8305.00
#
#    close_USD  volume  \
# 0    8041.46   25439
# 1    8239.81   23476
# 2    8233.49   17193
# 3    8526.98   19957
# 4    8381.24   21516
#
#    open_USD_lag1  \
# 0        8462.00
# 1        8330.00
# 2        8038.82
# 3        8238.01
# 4        8233.49
#
#    high_USD_lag1  \
# 0        8488.00
# 1        8464.00
# 2        8273.21
# 3        8390.80
# 4        8609.00
#
#    low_USD_lag1  \
# 0       8083.01
# 1       7979.00
# 2       7911.90
# 3       8095.73
# 4       8163.90
#
#    close_USD_lag1  ...  \
# 0         8330.00  ...
# 1         8041.46  ...
# 2         8239.81  ...
# 3         8233.49  ...
# 4         8526.98  ...
#
#    high_USD_lag9  \
# 0        9475.70
# 1        9390.00
# 2        9395.12
# 3        9016.80
# 4        8646.88
#
#    low_USD_lag9  \
# 0       9060.54
# 1       8965.00
# 2       8970.00
# 3       8341.00
# 4       8153.00
#
#    close_USD_lag9  \
# 0         9187.56
# 1         9310.00
# 2         9002.20
# 3         8400.00
# 4         8465.94
#
#    volume_lag9  \
# 0      25533.0
# 1      25673.0
# 2      25055.0
# 3      48227.0
# 4      40241.0
#
#    open_USD_lag10  \
# 0         9661.02
# 1         9365.00
# 2         9178.00
# 3         9310.00
# 4         9002.21
#
#    high_USD_lag10  \
# 0         9689.67
# 1         9475.70
# 2         9390.00
# 3         9395.12
# 4         9016.80
#
#    low_USD_lag10  \
# 0        9181.00
# 1        9060.54
# 2        8965.00
# 3        8970.00
# 4        8341.00
#
#    close_USD_lag10  \
# 0          9365.00
# 1          9187.56
# 2          9310.00
# 3          9002.20
# 4          8400.00
#
#    volume_lag10  \
# 0       33787.0
# 1       25533.0
# 2       25673.0
# 3       25055.0
# 4       48227.0
#
#    target_close_USD
# 0           8041.46
# 1           8239.81
# 2           8233.49
# 3           8526.98
# 4           8381.24
#
# [5 rows x 57 columns]

# %% [markdown]
# XGB train test preparation

# %%
# Prepare XGBoost train/test data

xgb_features = [
    col for col in xgb_data.columns
    if "lag" in col
]

X_xgb = xgb_data[xgb_features]
y_xgb = xgb_data["target_close_USD"]

train_size_xgb = int(len(xgb_data) * 0.8)

trainX_xgb = X_xgb.iloc[:train_size_xgb]
testX_xgb = X_xgb.iloc[train_size_xgb:]

trainY_xgb = y_xgb.iloc[:train_size_xgb]
testY_xgb = y_xgb.iloc[train_size_xgb:]

print("trainX_xgb shape:", trainX_xgb.shape)
print("testX_xgb shape:", testX_xgb.shape)
print("trainY_xgb shape:", trainY_xgb.shape)
print("testY_xgb shape:", testY_xgb.shape)
# Out:
# trainX_xgb shape: (792, 50)
# testX_xgb shape: (198, 50)
# trainY_xgb shape: (792,)
# testY_xgb shape: (198,)

# %% [markdown]
# Build & train model

# %%
# Build and train baseline XGBoost model

from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=100,
    max_depth=3,
    learning_rate=0.1,
    objective="reg:squarederror",
    random_state=42
)

xgb_model.fit(
    trainX_xgb,
    trainY_xgb
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# Evaluating on test data

# %%
# Evaluate XGBoost baseline on held-out future test data

xgb_test_pred = xgb_model.predict(testX_xgb)

xgb_rmse = np.sqrt(mean_squared_error(testY_xgb, xgb_test_pred))
xgb_mae = mean_absolute_error(testY_xgb, xgb_test_pred)

print(f"Baseline XGBoost Test RMSE: {xgb_rmse:.2f}")
print(f"Baseline XGBoost Test MAE: {xgb_mae:.2f}")
# Out:
# Baseline XGBoost Test RMSE: 10490.81
# Baseline XGBoost Test MAE: 6340.83

# %%
# Visualize baselineXGBoost predictions

plot_predictions(
    testY_xgb.values,
    xgb_test_pred,
    "Baseline XGBoost Test Predictions"
)

# %% [markdown]
# Modifying the XGB target to percent change instead of raw price

# %%
# Improved XGBoost: predict next-day percent change instead of raw price

xgb_return_data = bitcoin[["date"] + features].copy()

xgb_return_data["close_return"] = (
    xgb_return_data["close_USD"]
    .pct_change()
)                                                               # calculate daily percent return

lag_days = 10                                                   # use previous 10 days as predictors

for lag in range(1, lag_days + 1):

    for col in features:
        xgb_return_data[f"{col}_lag{lag}"] = (
            xgb_return_data[col]
            .shift(lag)
        )                                                       # previous feature values become lag predictors

    xgb_return_data[f"close_return_lag{lag}"] = (
        xgb_return_data["close_return"]
        .shift(lag)
    )                                                           # include lagged returns as predictors

xgb_return_data["target_return"] = (
    xgb_return_data["close_return"]
    .shift(-1)
)                                                               # predict next-day return

xgb_return_data["current_close_USD"] = (
    xgb_return_data["close_USD"]
)                                                               # keep current close price for reconstruction later

xgb_return_data = (
    xgb_return_data
    .dropna()
    .reset_index(drop=True)
)                                                               # remove rows without sufficient lag history

xgb_return_features = [
    col for col in xgb_return_data.columns
    if "lag" in col
]                                                               # use lagged values as predictors

X_xgb_return = xgb_return_data[xgb_return_features]
y_xgb_return = xgb_return_data["target_return"]

train_size_xgb_return = int(len(xgb_return_data) * 0.8)        # chronological 80/20 split

trainX_xgb_return = X_xgb_return.iloc[:train_size_xgb_return]
testX_xgb_return = X_xgb_return.iloc[train_size_xgb_return:]

trainY_xgb_return = y_xgb_return.iloc[:train_size_xgb_return]
testY_xgb_return = y_xgb_return.iloc[train_size_xgb_return:]

test_current_close = (
    xgb_return_data["current_close_USD"]
    .iloc[train_size_xgb_return:]
)                                                               # current price used to reconstruct next-day prediction

xgb_return_model = XGBRegressor(
    n_estimators=300,                                           # more trees for stronger learning
    max_depth=2,                                                # shallow trees reduce overfitting
    learning_rate=0.03,                                         # smaller learning steps
    subsample=0.8,                                              # random row sampling
    colsample_bytree=0.8,                                       # random feature sampling
    objective="reg:squarederror",
    random_state=42
)

xgb_return_model.fit(
    trainX_xgb_return,
    trainY_xgb_return
)

xgb_return_pred = xgb_return_model.predict(
    testX_xgb_return
)                                                               # predict next-day percent return

xgb_return_price_pred = (
    test_current_close.values * (1 + xgb_return_pred)
)                                                               # convert predicted return back to predicted price

xgb_return_price_actual = (
    test_current_close.values * (1 + testY_xgb_return.values)
)                                                               # actual next-day price

xgb_return_rmse = np.sqrt(
    mean_squared_error(
        xgb_return_price_actual,
        xgb_return_price_pred
    )
)

xgb_return_mae = mean_absolute_error(
    xgb_return_price_actual,
    xgb_return_price_pred
)

print(f"Improved XGBoost Test RMSE: {xgb_return_rmse:.2f}")
print(f"Improved XGBoost Test MAE: {xgb_return_mae:.2f}")

plot_predictions(
    xgb_return_price_actual,
    xgb_return_price_pred,
    "Improved XGBoost Return-Based Test Predictions"
)
# Out:
# Improved XGBoost Test RMSE: 925.44
# Improved XGBoost Test MAE: 564.97

# %%
# Compare baseline model performance

simple_rnn_rmse, simple_rnn_mae = evaluate_metrics(
    simple_rnn_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

lstm_rmse, lstm_mae = evaluate_metrics(
    lstm_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

gru_rmse, gru_mae = evaluate_metrics(
    gru_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

#rnn_rmse_exp1, rnn_mae_exp1 = evaluate_metrics(
  #  rnn_model_experiment1,
  #  testX_bitcoin,
  #  testY_bitcoin,
  #  scaler_bitcoin,
   # target_index
#)

#rnn_rmse_exp2, rnn_mae_exp2 = evaluate_metrics(
 #   rnn_model_experiment2,
  #  testX_bitcoin,
  #  testY_bitcoin,
  #  scaler_bitcoin,
  #  target_index
#)

#lstm_rmse_exp1, lstm_mae_exp1 = evaluate_metrics(
  #  lstm_model_experiment1,
  #  testX_bitcoin,
  #  testY_bitcoin,
  #  scaler_bitcoin,
  #  target_index
#)

model_comparison = pd.DataFrame({
    "Model": [
        "SimpleRNN",
        "LSTM",
        "GRU",
        "XGBoost raw price target",
        "XGBoost return target",
      #  "SimpleRNN larger RL",
      #  "Simple RNN larger RL and dropout",
      #  "LSTM with smaller look back"
    ],

    "RMSE": [
        simple_rnn_rmse,
        lstm_rmse,
        gru_rmse,
        xgb_rmse,
        xgb_return_rmse,
      #  rnn_rmse_exp1,
     #   rnn_rmse_exp2,
     #   lstm_rmse_exp1
    ],

    "MAE": [
        simple_rnn_mae,
        lstm_mae,
        gru_mae,
        xgb_mae,
        xgb_return_mae,
      #  rnn_mae_exp1,
      #  rnn_mae_exp2,
       # lstm_mae_exp1
    ]
})

model_comparison.sort_values("RMSE")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#                       Model  \
# 4     XGBoost return target
# 1                      LSTM
# 0                 SimpleRNN
# 2                       GRU
# 3  XGBoost raw price target
#
#            RMSE  \
# 4    925.441209
# 1   2398.133694
# 0   3953.111578
# 2   4732.625074
# 3  10490.806519
#
#            MAE
# 4   564.967019
# 1  1580.107556
# 0  2409.817394
# 2  3248.330800
# 3  6340.832358
