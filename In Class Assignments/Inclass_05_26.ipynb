# %% [markdown]
# # RNN Day 1 Housing Data

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd                                 # table/dataframe handling
import numpy as np                                  # numerical operations
import matplotlib.pyplot as plt                     # plotting

from sklearn.preprocessing import MinMaxScaler      # scales values to 0-1 range
from sklearn.metrics import mean_absolute_error, mean_squared_error 
                                                    # RMSE and MAE calculation

import tensorflow as tf
import random

from tensorflow.keras.models import Sequential      # sequential neural network API

from tensorflow.keras.layers import (
    Dense,                                          # standard fully connected layer
    SimpleRNN,                                      # recurrent neural network layer
    Conv1D,                                         # 1D convolution layer
    Flatten,
    Dropout                               # flatten multidimensional output
)

from tensorflow.keras.callbacks import EarlyStopping

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Loading the data

# %%
house = pd.read_csv("ma_lga_12345.csv")   # load housing dataset

house.head()                              # inspect first few rows
# Out:
#      saledate      MA   type  bedrooms
# 0  30/09/2007  441854  house         2
# 1  31/12/2007  441854  house         2
# 2  31/03/2008  441854  house         2
# 3  30/06/2008  441854  house         2
# 4  30/09/2008  451583  house         2

# %% [markdown]
# ### Inspecting the temporal nature of the data

# %%
print(house.shape)            # number of rows and columns
print(house.dtypes)           # variable data types
print(house.isna().sum())     # missing values per column

house.describe()              # summary statistics
# Out:
# (347, 4)
# saledate      str
# MA          int64
# type          str
# bedrooms    int64
# dtype: object
# saledate    0
# MA          0
# type        0
# bedrooms    0
# dtype: int64
#                  MA    bedrooms
# count  3.470000e+02  347.000000
# mean   5.481320e+05    2.867435
# std    1.701934e+05    1.239875
# min    3.167510e+05    1.000000
# 25%    4.277395e+05    2.000000
# 50%    5.077440e+05    3.000000
# 75%    6.275155e+05    4.000000
# max    1.017752e+06    5.000000

# %% [markdown]
# ## Defining useful functions

# %% [markdown]
# Formatting data for rolling windows

# %%
def create_sequences(dataset, look_back=2):

    X, y = [], []                          # containers for windows and targets

    for i in range(len(dataset) - look_back):

        X.append(dataset[i:i + look_back, :])   # rolling window
        y.append(dataset[i + look_back, 0])     # next timestep target

    return np.array(X), np.array(y)

# %% [markdown]
# Plotting training curves

# %%
def plot_training_curves(history, title):

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    axes[0].plot(history.history["loss"], label="Training Loss")
    axes[0].plot(history.history["val_loss"], label="Validation Loss")
    axes[0].set_title(title + " Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("MSE Loss")
    axes[0].set_ylim(0, 0.4)
    axes[0].legend()

    axes[1].plot(history.history["mean_absolute_error"], label="Training MAE")
    axes[1].plot(history.history["val_mean_absolute_error"], label="Validation MAE")
    axes[1].set_title(title + " MAE")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Mean Absolute Error")
    axes[1].set_ylim(0, 0.65)
    axes[1].legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Evaluating model performance on test data

# %%
def evaluate_and_plot(model, trainX, testX, trainY, testY, scaler, title):

    # Make predictions
    train_pred = model.predict(trainX)
    test_pred = model.predict(testX)

    # Convert scaled values back to original MA scale
    train_pred_inv = scaler.inverse_transform(train_pred)
    test_pred_inv = scaler.inverse_transform(test_pred)
    trainY_inv = scaler.inverse_transform(trainY.reshape(-1, 1))
    testY_inv = scaler.inverse_transform(testY.reshape(-1, 1))

    # Calculate RMSE on original scale
    train_rmse = np.sqrt(mean_squared_error(trainY_inv, train_pred_inv))
    test_rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))

    print(f"{title} Train RMSE: {train_rmse:.2f}")
    print(f"{title} Test RMSE: {test_rmse:.2f}")

    # Plot held-out future test predictions
    plt.figure(figsize=(10, 4))
    plt.plot(testY_inv, label="Actual")
    plt.plot(test_pred_inv, label="Predicted")

    plt.title(title + " Test Predictions")
    plt.xlabel("Test time index")
    plt.ylabel("MA")
    plt.ylim(0, 1200000)
    plt.ticklabel_format(style="plain", axis="y")
    plt.legend()
    plt.show()

# %% [markdown]
# Comparing forcasting performance metrics

# %%
def evaluate_metrics(model, testX, testY, scaler):

    test_pred = model.predict(testX)

    test_pred_inv = scaler.inverse_transform(test_pred)
    testY_inv = scaler.inverse_transform(testY.reshape(-1, 1))

    rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))
    mae = mean_absolute_error(testY_inv, test_pred_inv)

    return rmse, mae

# %% [markdown]
# ### Initial RNN & Performance

# %%
# Initial RNN

ma_sequence = house.copy()
ma_sequence = ma_sequence.sort_values("saledate").reset_index(drop=True)
                                                                # preserve chronological order

df_initial = ma_sequence[["MA"]].copy()                         # univariate forecasting feature

scaler_initial = MinMaxScaler(feature_range=(0, 1))
scaled_initial = scaler_initial.fit_transform(df_initial)       # scale feature
                                                                # neural networks train better on scaled values

look_back = 2                                                   # use previous 2 timesteps to predict next timestep

train_size = int(len(scaled_initial) * 0.8)                     # splits the dataset into training and test sets using an 80/20 split

train_initial = scaled_initial[:train_size]                     # earlier historical data
test_initial = scaled_initial[train_size:]                      # held-out future data

trainX_initial, trainY_initial = create_sequences(
    train_initial,
    look_back
)                                                               # rolling training windows

testX_initial, testY_initial = create_sequences(
    test_initial,
    look_back
)                                                               # rolling future test windows

print("trainX shape:", trainX_initial.shape)
print("testX shape:", testX_initial.shape)

initial_model = Sequential([
    SimpleRNN(
        16, #16 hidden units (slots to learn from memory)
        activation="tanh", #
        input_shape=(look_back, trainX_initial.shape[2]) #tells the layer to expect sequences of 2 timesteps, each with however many features are in trainX_initial
    ),                                                          # recurrent hidden layer

    Dense(1)                                                    # regression output layer
])

initial_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

initial_history = initial_model.fit(
    trainX_initial,
    trainY_initial,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,                                              # preserve temporal order
    verbose=1
)
# Out:
# trainX shape: (275, 2, 1)
# testX shape: (68, 2, 1)
# Epoch 1/100
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1027 - mean_absolute_error: 0.2647 - val_loss: 0.0916 - val_mean_absolute_error: 0.2549
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0868 - mean_absolute_error: 0.2409 - val_loss: 0.0807 - val_mean_absolute_error: 0.2324
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0758 - mean_absolute_error: 0.2230 - val_loss: 0.0740 - val_mean_absolute_error: 0.2187
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0682 - mean_absolute_error: 0.2089 - val_loss: 0.0702 - val_mean_absolute_error: 0.2103
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0633 - mean_absolute_error: 0.1992 - val_loss: 0.0686 - val_mean_absolute_error: 0.2046
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0602 - mean_absolute_error: 0.1938 - val_loss: 0.0682 - val_mean_absolute_error: 0.2039
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0583 - mean_absolute_error: 0.1910 - val_loss: 0.0685 - val_mean_absolute_error: 0.2070
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0571 - mean_absolute_error: 0.1894 - val_loss: 0.0690 - val_mean_absolute_error: 0.2099
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0564 - mean_absolute_error: 0.1884 - val_loss: 0.0697 - val_mean_absolute_error: 0.2123
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0560 - mean_absolute_error: 0.1879 - val_loss: 0.0704 - val_mean_absolute_error: 0.2142
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0557 - mean_absolute_error: 0.1877 - val_loss: 0.0710 - val_mean_absolute_error: 0.2158
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0555 - mean_absolute_error: 0.1877 - val_loss: 0.0716 - val_mean_absolute_error: 0.2171
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0554 - mean_absolute_error: 0.1877 - val_loss: 0.0720 - val_mean_absolute_error: 0.2181
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0553 - mean_absolute_error: 0.1877 - val_loss: 0.0724 - val_mean_absolute_error: 0.2188
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 0.0553 - mean_absolute_error: 0.1877 - val_loss: 0.0726 - val_mean_absolute_error: 0.2193
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0552 - mean_absolute_error: 0.1877 - val_loss: 0.0729 - val_mean_absolute_error: 0.2198
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0552 - mean_absolute_error: 0.1877 - val_loss: 0.0731 - val_mean_absolute_error: 0.2201
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 0.0551 - mean_absolute_error: 0.1877 - val_loss: 0.0732 - val_mean_absolute_error: 0.2203
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 0.0551 - mean_absolute_error: 0.1877 - val_loss: 0.0734 - val_mean_absolute_error: 0.2205
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 0.0551 - mean_absolute_error: 0.1877 - val_loss: 0.0735 - val_mean_absolute_error: 0.2207
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0551 - mean_absolute_error: 0.1877 - val_loss: 0.0736 - val_mean_absolute_error: 0.2208
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0550 - mean_absolute_error: 0.1877 - val_loss: 0.0736 - val_mean_absolute_error: 0.2208
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0550 - mean_absolute_error: 0.1877 - val_loss: 0.0737 - val_mean_absolute_error: 0.2209
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 0.0550 - mean_absolute_error: 0.1876 - val_loss: 0.0737 - val_mean_absolute_error: 0.2210
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 0.0550 - mean_absolute_error: 0.1876 - val_loss: 0.0738 - val_mean_absolute_error: 0.2210
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 0.0550 - mean_absolute_error: 0.1876 - val_loss: 0.0738 - val_mean_absolute_error: 0.2210
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 0.0549 - mean_absolute_error: 0.1876 - val_loss: 0.0738 - val_mean_absolute_error: 0.2210
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0549 - mean_absolute_error: 0.1876 - val_loss: 0.0739 - val_mean_absolute_error: 0.2210
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0549 - mean_absolute_error: 0.1875 - val_loss: 0.0739 - val_mean_absolute_error: 0.2211
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 0.0549 - mean_absolute_error: 0.1875 - val_loss: 0.0739 - val_mean_absolute_error: 0.2211
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 0.0549 - mean_absolute_error: 0.1875 - val_loss: 0.0739 - val_mean_absolute_error: 0.2211
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.0549 - mean_absolute_error: 0.1875 - val_loss: 0.0740 - val_mean_absolute_error: 0.2211
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0549 - mean_absolute_error: 0.1875 - val_loss: 0.0740 - val_mean_absolute_error: 0.2211
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0549 - mean_absolute_error: 0.1875 - val_loss: 0.0740 - val_mean_absolute_error: 0.2211
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 0.0548 - mean_absolute_error: 0.1874 - val_loss: 0.0740 - val_mean_absolute_error: 0.2211
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0548 - mean_absolute_error: 0.1874 - val_loss: 0.0740 - val_mean_absolute_error: 0.2211
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 0.0548 - mean_absolute_error: 0.1874 - val_loss: 0.0740 - val_mean_absolute_error: 0.2211
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 0.0548 - mean_absolute_error: 0.1874 - val_loss: 0.0740 - val_mean_absolute_error: 0.2210
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0548 - mean_absolute_error: 0.1874 - val_loss: 0.0740 - val_mean_absolute_error: 0.2210
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 0.0548 - mean_absolute_error: 0.1874 - val_loss: 0.0741 - val_mean_absolute_error: 0.2210
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 0.0548 - mean_absolute_error: 0.1874 - val_loss: 0.0741 - val_mean_absolute_error: 0.2210
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0548 - mean_absolute_error: 0.1873 - val_loss: 0.0741 - val_mean_absolute_error: 0.2210
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0548 - mean_absolute_error: 0.1873 - val_loss: 0.0741 - val_mean_absolute_error: 0.2210
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0548 - mean_absolute_error: 0.1873 - val_loss: 0.0741 - val_mean_absolute_error: 0.2210
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 0.0548 - mean_absolute_error: 0.1873 - val_loss: 0.0741 - val_mean_absolute_error: 0.2210
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0548 - mean_absolute_error: 0.1873 - val_loss: 0.0741 - val_mean_absolute_error: 0.2210
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0548 - mean_absolute_error: 0.1873 - val_loss: 0.0741 - val_mean_absolute_error: 0.2210
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 0.0547 - mean_absolute_error: 0.1873 - val_loss: 0.0741 - val_mean_absolute_error: 0.2210
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.0547 - mean_absolute_error: 0.1873 - val_loss: 0.0741 - val_mean_absolute_error: 0.2210
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1873 - val_loss: 0.0741 - val_mean_absolute_error: 0.2210
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1873 - val_loss: 0.0741 - val_mean_absolute_error: 0.2210
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1873 - val_loss: 0.0742 - val_mean_absolute_error: 0.2210
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2210
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2210
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2210
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2210
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2210
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2210
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2209
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2209
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2209
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2209
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2209
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2209
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2209
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2209
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1872 - val_loss: 0.0742 - val_mean_absolute_error: 0.2209
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2209
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2208
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2208
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2208
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2208
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2208
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1871 - val_loss: 0.0743 - val_mean_absolute_error: 0.2208
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0743 - val_mean_absolute_error: 0.2208
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0743 - val_mean_absolute_error: 0.2208
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0743 - val_mean_absolute_error: 0.2208
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0743 - val_mean_absolute_error: 0.2208
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0744 - val_mean_absolute_error: 0.2208
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0744 - val_mean_absolute_error: 0.2208
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0744 - val_mean_absolute_error: 0.2208
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0744 - val_mean_absolute_error: 0.2208
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0744 - val_mean_absolute_error: 0.2208
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0744 - val_mean_absolute_error: 0.2208
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0744 - val_mean_absolute_error: 0.2208
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0744 - val_mean_absolute_error: 0.2208
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0744 - val_mean_absolute_error: 0.2208
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mean_absolute_error: 0.1870 - val_loss: 0.0744 - val_mean_absolute_error: 0.2208

# %% [markdown]
# Training curves

# %%
plot_training_curves(
    initial_history,
    "Initial RNN"
)

# %% [markdown]
# Test data evaluation

# %%
evaluate_and_plot(
    initial_model,
    trainX_initial,
    testX_initial,
    trainY_initial,
    testY_initial,
    scaler_initial,
    "Initial RNN"
)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Initial RNN Train RMSE: 168752.01
# Initial RNN Test RMSE: 171397.52

# %% [markdown]
# ### Initial MA data re-evaluation

# %%
# Plot the original MA sequence exactly as provided

plt.figure(figsize=(10, 4))

plt.plot(
    ma_sequence["saledate"],
    ma_sequence["MA"]
)

plt.title("Original MA sequence")
plt.xlabel("Date")
plt.ylabel("MA")

plt.ylim(0, 1200000)

plt.ticklabel_format(
    style='plain',
    axis='y'
)                                        

plt.xticks(rotation=45)

plt.show()

# %%
# Plot each subgroup MA sequence separately

house["saledate"] = pd.to_datetime(
    house["saledate"],
    dayfirst=True
)

# Plot each subgroup MA sequence separately

house["saledate"] = pd.to_datetime(
    house["saledate"],
    dayfirst=True
)

plt.figure(figsize=(12, 6))

for (property_type, bedrooms), group in house.groupby(["type", "bedrooms"]):

    group = group.sort_values("saledate")      # chronological ordering

    plt.plot(
        group["saledate"],
        group["MA"],
        label=f"{property_type}, {bedrooms} bed"
    )

plt.title("MA sequences by property subgroup")

plt.xlabel("Date")
plt.ylabel("MA")

plt.ylim(0, 1200000)

plt.ticklabel_format(
    style='plain',
    axis='y'
)

plt.xticks(rotation=45)

plt.legend(
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)

plt.tight_layout()

plt.show()

# %% [markdown]
# Inspecting the first window

# %%
print("trainX_initial shape:", trainX_initial.shape)

window_id = 0

ma_sequence.iloc[
    window_id : window_id + look_back + 1
][["saledate", "type", "bedrooms", "MA"]]
# Out:
# trainX_initial shape: (275, 2, 1)
#      saledate   type  bedrooms      MA
# 0  30/06/2007   unit         2  368817
# 1  30/06/2007  house         4  548969
# 2  30/06/2007  house         3  421291

# %% [markdown]
# Rows 0 and 1 are the 2 input timesteps (X)
#
# Row 2 is the target to predict (Y)

# %% [markdown]
# ### Creating market-level MA data

# %%
# Create market-level MA sequence

house["saledate"] = pd.to_datetime(
    house["saledate"],
    dayfirst=True
)                                                    # ensure dates sort chronologically

market_ma = (
    house
    .groupby("saledate")["MA"]
    .mean()
    .reset_index()
    .sort_values("saledate")
    .reset_index(drop=True)
)                                                    # average subgroup MAs per date

# Visualize market-level MA

plt.figure(figsize=(10, 4))

plt.plot(
    market_ma["saledate"],
    market_ma["MA"]
)

plt.title("Market-level MA: one average value per date")
plt.xlabel("Date")
plt.ylabel("Average MA")

plt.ylim(0, 1200000)
plt.ticklabel_format(style="plain", axis="y")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Preparing market-level MA data for variety of models

# %%
# Prepare market-level MA data for all fixed-data models

df_market = market_ma[["MA"]].copy()                            # cleaned one-value-per-date MA series

scaler_market = MinMaxScaler(feature_range=(0, 1))              # scale MA values for neural networks
scaled_market = scaler_market.fit_transform(df_market)

look_back = 2                                                   # use 2 previous timesteps to predict next timestep

train_size = int(len(scaled_market) * 0.8)                      # chronological 80/20 split

train_market = scaled_market[:train_size]                       # earlier historical data
test_market = scaled_market[train_size:]                        # held-out future data

trainX_market, trainY_market = create_sequences(
    train_market,
    look_back
)                                                               # sequence windows for RNN/CNN

testX_market, testY_market = create_sequences(
    test_market,
    look_back
)                                                               # future test windows for RNN/CNN

trainX_market_mlp = trainX_market.reshape(
    trainX_market.shape[0],
    trainX_market.shape[1] * trainX_market.shape[2]
)                                                               # flattened windows for MLP

testX_market_mlp = testX_market.reshape(
    testX_market.shape[0],
    testX_market.shape[1] * testX_market.shape[2]
)                                                               # flattened test windows for MLP

print("RNN/CNN trainX_market shape:", trainX_market.shape)
print("RNN/CNN testX_market shape:", testX_market.shape)

print("MLP trainX_market_mlp shape:", trainX_market_mlp.shape)
print("MLP testX_market_mlp shape:", testX_market_mlp.shape)
# Out:
# RNN/CNN trainX_market shape: (38, 2, 1)
# RNN/CNN testX_market shape: (9, 2, 1)
# MLP trainX_market_mlp shape: (38, 2)
# MLP testX_market_mlp shape: (9, 2)

# %% [markdown]
# ### Inspecting the tensors

# %% [markdown]
# Shape & window 0 values

# %%
print("trainX_market shape:", trainX_market.shape)

window_id = 0

market_ma.iloc[
    window_id : window_id + look_back + 1
][["saledate", "MA"]]
# Out:
# trainX_market shape: (38, 2, 1)
#     saledate             MA
# 0 2007-03-31  485130.000000
# 1 2007-06-30  446359.000000
# 2 2007-09-30  505957.666667

# %% [markdown]
# Scale window 0

# %%
# Visualize one input window and its target

window_id = 0

print("Input window:")
print(trainX_market[window_id].flatten())

print("Target:")
print(trainY_market[window_id])
# Out:
# Input window:
# [0.22095731 0.        ]
# Target:
# 0.33965492068299463

# %% [markdown]
# Input window: [0.221, 0.0] - These are the 2 scaled MA values (the look_back timesteps)
#
# Target: 0.339 - This is the scaled version of row 2/what the RNN is trying to predict

# %% [markdown]
# ### Market-level RNN model & evaluation

# %%
# Build and train market-level RNN model

market_rnn_model = Sequential([
    SimpleRNN(
        16,
        activation="tanh",
        input_shape=(look_back, trainX_market.shape[2])
    ),
    Dense(1)
])

market_rnn_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

market_rnn_history = market_rnn_model.fit(
    trainX_market,
    trainY_market,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/100
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0500 - mean_absolute_error: 0.2169 - val_loss: 0.1204 - val_mean_absolute_error: 0.3453
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0223 - mean_absolute_error: 0.1427 - val_loss: 0.0597 - val_mean_absolute_error: 0.2425
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - mean_absolute_error: 0.0768 - val_loss: 0.0229 - val_mean_absolute_error: 0.1492
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0272 - val_loss: 0.0061 - val_mean_absolute_error: 0.0754
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0423 - val_loss: 0.0013 - val_mean_absolute_error: 0.0306
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - mean_absolute_error: 0.0608 - val_loss: 6.6128e-04 - val_mean_absolute_error: 0.0215
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mean_absolute_error: 0.0612 - val_loss: 0.0013 - val_mean_absolute_error: 0.0302
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mean_absolute_error: 0.0506 - val_loss: 0.0036 - val_mean_absolute_error: 0.0565
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - mean_absolute_error: 0.0368 - val_loss: 0.0077 - val_mean_absolute_error: 0.0849
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022 - mean_absolute_error: 0.0303 - val_loss: 0.0118 - val_mean_absolute_error: 0.1063
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - mean_absolute_error: 0.0339 - val_loss: 0.0140 - val_mean_absolute_error: 0.1163
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022 - mean_absolute_error: 0.0350 - val_loss: 0.0138 - val_mean_absolute_error: 0.1150
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0324 - val_loss: 0.0117 - val_mean_absolute_error: 0.1061
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0289 - val_loss: 0.0094 - val_mean_absolute_error: 0.0944
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0273 - val_loss: 0.0076 - val_mean_absolute_error: 0.0846
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0282 - val_loss: 0.0067 - val_mean_absolute_error: 0.0792
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0289 - val_loss: 0.0066 - val_mean_absolute_error: 0.0787
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0285 - val_loss: 0.0070 - val_mean_absolute_error: 0.0814
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0279 - val_loss: 0.0077 - val_mean_absolute_error: 0.0851
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0276 - val_loss: 0.0081 - val_mean_absolute_error: 0.0876
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0275 - val_loss: 0.0082 - val_mean_absolute_error: 0.0881
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0273 - val_loss: 0.0079 - val_mean_absolute_error: 0.0866
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0270 - val_loss: 0.0075 - val_mean_absolute_error: 0.0842
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018 - mean_absolute_error: 0.0270 - val_loss: 0.0071 - val_mean_absolute_error: 0.0818
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0270 - val_loss: 0.0068 - val_mean_absolute_error: 0.0802
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - mean_absolute_error: 0.0270 - val_loss: 0.0067 - val_mean_absolute_error: 0.0795
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0270 - val_loss: 0.0067 - val_mean_absolute_error: 0.0795
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0268 - val_loss: 0.0067 - val_mean_absolute_error: 0.0796
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0267 - val_loss: 0.0067 - val_mean_absolute_error: 0.0795
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0266 - val_loss: 0.0066 - val_mean_absolute_error: 0.0789
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0265 - val_loss: 0.0064 - val_mean_absolute_error: 0.0780
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0265 - val_loss: 0.0063 - val_mean_absolute_error: 0.0770
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0264 - val_loss: 0.0062 - val_mean_absolute_error: 0.0762
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0264 - val_loss: 0.0061 - val_mean_absolute_error: 0.0756
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0263 - val_loss: 0.0060 - val_mean_absolute_error: 0.0751
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0262 - val_loss: 0.0059 - val_mean_absolute_error: 0.0748
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0262 - val_loss: 0.0059 - val_mean_absolute_error: 0.0743
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0261 - val_loss: 0.0058 - val_mean_absolute_error: 0.0738
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0261 - val_loss: 0.0057 - val_mean_absolute_error: 0.0732
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0260 - val_loss: 0.0056 - val_mean_absolute_error: 0.0727
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0260 - val_loss: 0.0055 - val_mean_absolute_error: 0.0721
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0259 - val_loss: 0.0055 - val_mean_absolute_error: 0.0717
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0259 - val_loss: 0.0054 - val_mean_absolute_error: 0.0713
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0258 - val_loss: 0.0053 - val_mean_absolute_error: 0.0709
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0053 - val_mean_absolute_error: 0.0705
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0052 - val_mean_absolute_error: 0.0701
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0051 - val_mean_absolute_error: 0.0696
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0256 - val_loss: 0.0051 - val_mean_absolute_error: 0.0693
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0256 - val_loss: 0.0050 - val_mean_absolute_error: 0.0689
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0255 - val_loss: 0.0050 - val_mean_absolute_error: 0.0685
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0255 - val_loss: 0.0049 - val_mean_absolute_error: 0.0682
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0255 - val_loss: 0.0049 - val_mean_absolute_error: 0.0679
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0254 - val_loss: 0.0048 - val_mean_absolute_error: 0.0676
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0254 - val_loss: 0.0048 - val_mean_absolute_error: 0.0673
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0254 - val_loss: 0.0048 - val_mean_absolute_error: 0.0670
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 0.0047 - val_mean_absolute_error: 0.0667
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 0.0047 - val_mean_absolute_error: 0.0664
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 0.0046 - val_mean_absolute_error: 0.0662
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0046 - val_mean_absolute_error: 0.0659
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0046 - val_mean_absolute_error: 0.0657
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0045 - val_mean_absolute_error: 0.0654
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0045 - val_mean_absolute_error: 0.0652
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0045 - val_mean_absolute_error: 0.0650
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0045 - val_mean_absolute_error: 0.0648
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0044 - val_mean_absolute_error: 0.0646
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0044 - val_mean_absolute_error: 0.0644
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0044 - val_mean_absolute_error: 0.0642
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0044 - val_mean_absolute_error: 0.0640
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0043 - val_mean_absolute_error: 0.0639
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0043 - val_mean_absolute_error: 0.0637
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0043 - val_mean_absolute_error: 0.0635
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0043 - val_mean_absolute_error: 0.0634
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0042 - val_mean_absolute_error: 0.0632
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0042 - val_mean_absolute_error: 0.0631
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0042 - val_mean_absolute_error: 0.0629
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0042 - val_mean_absolute_error: 0.0628
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0042 - val_mean_absolute_error: 0.0627
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0042 - val_mean_absolute_error: 0.0625
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0041 - val_mean_absolute_error: 0.0624
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0041 - val_mean_absolute_error: 0.0623
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0622
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0621
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0619
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0618
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0617
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0040 - val_mean_absolute_error: 0.0616
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0615
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0614
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0613
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0613
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0612
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0611
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0040 - val_mean_absolute_error: 0.0610
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0609
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0608
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0607
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0607
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0606
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0605
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0244 - val_loss: 0.0039 - val_mean_absolute_error: 0.0604

# %% [markdown]
# Training curves

# %%
plot_training_curves(
    market_rnn_history,
    "Market-level RNN"
)

# %% [markdown]
# Test data evaluation

# %%
evaluate_and_plot(
    market_rnn_model,
    trainX_market,
    testX_market,
    trainY_market,
    testY_market,
    scaler_market,
    "Market-level RNN"
)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Market-level RNN Train RMSE: 8131.16
# Market-level RNN Test RMSE: 15985.01

# %% [markdown]
# ### Market level MLP and evaluation

# %%
# Build and train market-level MLP model

market_mlp_model = Sequential([
    Dense(
        32,
        activation="relu",
        input_shape=(trainX_market_mlp.shape[1],)
    ),
    Dense(
        16,
        activation="relu"
    ),
    Dense(1)
])

market_mlp_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

market_mlp_history = market_mlp_model.fit(
    trainX_market_mlp,
    trainY_market,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/100
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0963 - mean_absolute_error: 0.2989 - val_loss: 0.2720 - val_mean_absolute_error: 0.5195
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0762 - mean_absolute_error: 0.2646 - val_loss: 0.2254 - val_mean_absolute_error: 0.4728
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0604 - mean_absolute_error: 0.2341 - val_loss: 0.1870 - val_mean_absolute_error: 0.4305
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0456 - mean_absolute_error: 0.2016 - val_loss: 0.1498 - val_mean_absolute_error: 0.3851
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0322 - mean_absolute_error: 0.1670 - val_loss: 0.1146 - val_mean_absolute_error: 0.3366
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0213 - mean_absolute_error: 0.1330 - val_loss: 0.0845 - val_mean_absolute_error: 0.2888
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0130 - mean_absolute_error: 0.1011 - val_loss: 0.0601 - val_mean_absolute_error: 0.2432
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074 - mean_absolute_error: 0.0734 - val_loss: 0.0413 - val_mean_absolute_error: 0.2013
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - mean_absolute_error: 0.0562 - val_loss: 0.0279 - val_mean_absolute_error: 0.1649
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - mean_absolute_error: 0.0446 - val_loss: 0.0189 - val_mean_absolute_error: 0.1352
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024 - mean_absolute_error: 0.0378 - val_loss: 0.0133 - val_mean_absolute_error: 0.1128
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - mean_absolute_error: 0.0375 - val_loss: 0.0101 - val_mean_absolute_error: 0.0979
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0413 - val_loss: 0.0086 - val_mean_absolute_error: 0.0901
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0434 - val_loss: 0.0083 - val_mean_absolute_error: 0.0883
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0432 - val_loss: 0.0087 - val_mean_absolute_error: 0.0908
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0416 - val_loss: 0.0097 - val_mean_absolute_error: 0.0958
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0396 - val_loss: 0.0109 - val_mean_absolute_error: 0.1018
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0382 - val_loss: 0.0121 - val_mean_absolute_error: 0.1076
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0378 - val_loss: 0.0131 - val_mean_absolute_error: 0.1123
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0379 - val_loss: 0.0139 - val_mean_absolute_error: 0.1155
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0377 - val_loss: 0.0143 - val_mean_absolute_error: 0.1172
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0375 - val_loss: 0.0143 - val_mean_absolute_error: 0.1174
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0371 - val_loss: 0.0141 - val_mean_absolute_error: 0.1165
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0365 - val_loss: 0.0137 - val_mean_absolute_error: 0.1150
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0359 - val_loss: 0.0133 - val_mean_absolute_error: 0.1131
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0354 - val_loss: 0.0129 - val_mean_absolute_error: 0.1111
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0348 - val_loss: 0.0125 - val_mean_absolute_error: 0.1094
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - val_loss: 0.0121 - val_mean_absolute_error: 0.1079
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0338 - val_loss: 0.0119 - val_mean_absolute_error: 0.1068
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0334 - val_loss: 0.0117 - val_mean_absolute_error: 0.1059
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0330 - val_loss: 0.0115 - val_mean_absolute_error: 0.1051
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0326 - val_loss: 0.0114 - val_mean_absolute_error: 0.1045
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0321 - val_loss: 0.0112 - val_mean_absolute_error: 0.1039
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0317 - val_loss: 0.0111 - val_mean_absolute_error: 0.1033
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0317 - val_loss: 0.0113 - val_mean_absolute_error: 0.1042
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0306 - val_loss: 0.0106 - val_mean_absolute_error: 0.1010
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0293 - val_loss: 0.0102 - val_mean_absolute_error: 0.0988
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0287 - val_loss: 0.0099 - val_mean_absolute_error: 0.0973
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0280 - val_loss: 0.0096 - val_mean_absolute_error: 0.0960
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0275 - val_loss: 0.0094 - val_mean_absolute_error: 0.0947
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0266 - val_loss: 0.0091 - val_mean_absolute_error: 0.0932
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0258 - val_loss: 0.0088 - val_mean_absolute_error: 0.0916
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0254 - val_loss: 0.0085 - val_mean_absolute_error: 0.0901
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0249 - val_loss: 0.0082 - val_mean_absolute_error: 0.0885
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0244 - val_loss: 0.0079 - val_mean_absolute_error: 0.0868
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0239 - val_loss: 0.0076 - val_mean_absolute_error: 0.0852
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0235 - val_loss: 0.0073 - val_mean_absolute_error: 0.0834
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0230 - val_loss: 0.0070 - val_mean_absolute_error: 0.0818
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0226 - val_loss: 0.0068 - val_mean_absolute_error: 0.0803
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0222 - val_loss: 0.0066 - val_mean_absolute_error: 0.0790
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0218 - val_loss: 0.0064 - val_mean_absolute_error: 0.0778
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - mean_absolute_error: 0.0214 - val_loss: 0.0062 - val_mean_absolute_error: 0.0766
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9056e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0060 - val_mean_absolute_error: 0.0755
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6462e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0058 - val_mean_absolute_error: 0.0745
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3160e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0057 - val_mean_absolute_error: 0.0735
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0640e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0056 - val_mean_absolute_error: 0.0726
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8084e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0054 - val_mean_absolute_error: 0.0717
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5669e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0053 - val_mean_absolute_error: 0.0708
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2883e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0051 - val_mean_absolute_error: 0.0697
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0884e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0050 - val_mean_absolute_error: 0.0686
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8618e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0048 - val_mean_absolute_error: 0.0676
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7107e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0047 - val_mean_absolute_error: 0.0667
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4770e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0046 - val_mean_absolute_error: 0.0656
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2799e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0044 - val_mean_absolute_error: 0.0645
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1166e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0043 - val_mean_absolute_error: 0.0636
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9992e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0042 - val_mean_absolute_error: 0.0629
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8212e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0041 - val_mean_absolute_error: 0.0622
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6454e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0040 - val_mean_absolute_error: 0.0614
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4761e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0039 - val_mean_absolute_error: 0.0604
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3571e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0038 - val_mean_absolute_error: 0.0595
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2080e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0037 - val_mean_absolute_error: 0.0587
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0849e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0036 - val_mean_absolute_error: 0.0579
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9526e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0035 - val_mean_absolute_error: 0.0571
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8087e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0034 - val_mean_absolute_error: 0.0562
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7122e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0033 - val_mean_absolute_error: 0.0552
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5897e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0032 - val_mean_absolute_error: 0.0544
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4827e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0031 - val_mean_absolute_error: 0.0537
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3872e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0030 - val_mean_absolute_error: 0.0531
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2766e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0029 - val_mean_absolute_error: 0.0524
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1636e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0029 - val_mean_absolute_error: 0.0518
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0725e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0028 - val_mean_absolute_error: 0.0513
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9774e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0028 - val_mean_absolute_error: 0.0508
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8932e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0027 - val_mean_absolute_error: 0.0505
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7916e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0027 - val_mean_absolute_error: 0.0500
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6910e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0026 - val_mean_absolute_error: 0.0494
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6119e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0026 - val_mean_absolute_error: 0.0488
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5516e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0025 - val_mean_absolute_error: 0.0484
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4546e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0025 - val_mean_absolute_error: 0.0480
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3622e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0024 - val_mean_absolute_error: 0.0475
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2781e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0024 - val_mean_absolute_error: 0.0469
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2065e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0023 - val_mean_absolute_error: 0.0466
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1327e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0023 - val_mean_absolute_error: 0.0462
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0575e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0023 - val_mean_absolute_error: 0.0457
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9766e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0022 - val_mean_absolute_error: 0.0451
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9181e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0022 - val_mean_absolute_error: 0.0446
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8662e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0021 - val_mean_absolute_error: 0.0442
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7958e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0021 - val_mean_absolute_error: 0.0438
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7290e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0020 - val_mean_absolute_error: 0.0434
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6603e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0020 - val_mean_absolute_error: 0.0430
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6022e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0020 - val_mean_absolute_error: 0.0428

# %% [markdown]
# - No concept of sequence or time, it just sees the input as a flat vector
# - Dense(32, relu): first hidden layer with 32 neurons, takes the flattened input (lookback window squished into a 1D array)
# - Dense(16, relu): second hidden layer with 16 neurons, refines the patterns learned by the first layer
# - Dense(1): output layer, same as the RNN, predicts one continuous value

# %% [markdown]
# Training curves MLP

# %%
plot_training_curves(
    market_mlp_history,
    "Market-level MLP"
)

# %% [markdown]
# Test data evaluation MLP

# %%
evaluate_and_plot(
    market_mlp_model,
    trainX_market_mlp,
    testX_market_mlp,
    trainY_market,
    testY_market,
    scaler_market,
    "Market-level MLP"
)
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x165fa11c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/stepWARNING:tensorflow:6 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x165fa11c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Market-level MLP Train RMSE: 4631.41
# Market-level MLP Test RMSE: 10526.73

# %% [markdown]
# ### Market level CNN & evaluation

# %%
# Build and train market-level 1D CNN model

market_cnn_model = Sequential([
    Conv1D(
        filters=16,                         # learn 16 temporal pattern detectors
        kernel_size=2,                      # each filter looks across 2 neighboring timesteps
        activation="relu",
        input_shape=(look_back, trainX_market.shape[2])
    ),                                      # input shape = timesteps, features

    Flatten(),                              # convert CNN output to flat vector for Dense layer

    Dense(1)                                # regression output layer
])

market_cnn_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

market_cnn_history = market_cnn_model.fit(
    trainX_market,
    trainY_market,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,                          # preserve temporal order
    verbose=1
)
# Out:
# Epoch 1/100
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0999 - mean_absolute_error: 0.3029 - val_loss: 0.2975 - val_mean_absolute_error: 0.5433
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0884 - mean_absolute_error: 0.2840 - val_loss: 0.2710 - val_mean_absolute_error: 0.5184
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0778 - mean_absolute_error: 0.2656 - val_loss: 0.2458 - val_mean_absolute_error: 0.4937
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0681 - mean_absolute_error: 0.2474 - val_loss: 0.2222 - val_mean_absolute_error: 0.4693
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0592 - mean_absolute_error: 0.2297 - val_loss: 0.2003 - val_mean_absolute_error: 0.4455
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0514 - mean_absolute_error: 0.2127 - val_loss: 0.1801 - val_mean_absolute_error: 0.4224
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0445 - mean_absolute_error: 0.1967 - val_loss: 0.1618 - val_mean_absolute_error: 0.4001
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0385 - mean_absolute_error: 0.1815 - val_loss: 0.1457 - val_mean_absolute_error: 0.3796
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0332 - mean_absolute_error: 0.1671 - val_loss: 0.1313 - val_mean_absolute_error: 0.3604
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0285 - mean_absolute_error: 0.1539 - val_loss: 0.1183 - val_mean_absolute_error: 0.3420
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0244 - mean_absolute_error: 0.1411 - val_loss: 0.1065 - val_mean_absolute_error: 0.3243
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0207 - mean_absolute_error: 0.1289 - val_loss: 0.0958 - val_mean_absolute_error: 0.3074
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0176 - mean_absolute_error: 0.1172 - val_loss: 0.0860 - val_mean_absolute_error: 0.2912
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0149 - mean_absolute_error: 0.1069 - val_loss: 0.0773 - val_mean_absolute_error: 0.2759
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0126 - mean_absolute_error: 0.0976 - val_loss: 0.0694 - val_mean_absolute_error: 0.2614
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0107 - mean_absolute_error: 0.0889 - val_loss: 0.0624 - val_mean_absolute_error: 0.2477
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090 - mean_absolute_error: 0.0810 - val_loss: 0.0562 - val_mean_absolute_error: 0.2349
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0077 - mean_absolute_error: 0.0749 - val_loss: 0.0507 - val_mean_absolute_error: 0.2230
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066 - mean_absolute_error: 0.0702 - val_loss: 0.0459 - val_mean_absolute_error: 0.2119
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0058 - mean_absolute_error: 0.0659 - val_loss: 0.0416 - val_mean_absolute_error: 0.2017
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mean_absolute_error: 0.0623 - val_loss: 0.0379 - val_mean_absolute_error: 0.1924
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mean_absolute_error: 0.0590 - val_loss: 0.0347 - val_mean_absolute_error: 0.1840
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mean_absolute_error: 0.0561 - val_loss: 0.0319 - val_mean_absolute_error: 0.1763
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mean_absolute_error: 0.0535 - val_loss: 0.0295 - val_mean_absolute_error: 0.1694
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mean_absolute_error: 0.0511 - val_loss: 0.0275 - val_mean_absolute_error: 0.1633
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0491 - val_loss: 0.0257 - val_mean_absolute_error: 0.1579
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0475 - val_loss: 0.0242 - val_mean_absolute_error: 0.1531
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0460 - val_loss: 0.0230 - val_mean_absolute_error: 0.1490
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0449 - val_loss: 0.0219 - val_mean_absolute_error: 0.1453
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0439 - val_loss: 0.0210 - val_mean_absolute_error: 0.1422
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0432 - val_loss: 0.0202 - val_mean_absolute_error: 0.1395
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0426 - val_loss: 0.0195 - val_mean_absolute_error: 0.1371
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0420 - val_loss: 0.0190 - val_mean_absolute_error: 0.1351
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0416 - val_loss: 0.0185 - val_mean_absolute_error: 0.1334
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0412 - val_loss: 0.0181 - val_mean_absolute_error: 0.1320
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0408 - val_loss: 0.0178 - val_mean_absolute_error: 0.1308
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0405 - val_loss: 0.0175 - val_mean_absolute_error: 0.1298
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0401 - val_loss: 0.0174 - val_mean_absolute_error: 0.1291
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0398 - val_loss: 0.0171 - val_mean_absolute_error: 0.1281
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0395 - val_loss: 0.0168 - val_mean_absolute_error: 0.1271
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0392 - val_loss: 0.0166 - val_mean_absolute_error: 0.1262
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0390 - val_loss: 0.0164 - val_mean_absolute_error: 0.1255
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0388 - val_loss: 0.0163 - val_mean_absolute_error: 0.1249
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0386 - val_loss: 0.0161 - val_mean_absolute_error: 0.1243
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0384 - val_loss: 0.0160 - val_mean_absolute_error: 0.1238
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0382 - val_loss: 0.0159 - val_mean_absolute_error: 0.1233
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0379 - val_loss: 0.0157 - val_mean_absolute_error: 0.1228
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0027 - mean_absolute_error: 0.0377 - val_loss: 0.0156 - val_mean_absolute_error: 0.1223
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0376 - val_loss: 0.0155 - val_mean_absolute_error: 0.1218
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0373 - val_loss: 0.0154 - val_mean_absolute_error: 0.1213
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0371 - val_loss: 0.0153 - val_mean_absolute_error: 0.1208
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0370 - val_loss: 0.0151 - val_mean_absolute_error: 0.1204
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0368 - val_loss: 0.0150 - val_mean_absolute_error: 0.1199
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0366 - val_loss: 0.0149 - val_mean_absolute_error: 0.1194
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0364 - val_loss: 0.0148 - val_mean_absolute_error: 0.1190
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0362 - val_loss: 0.0147 - val_mean_absolute_error: 0.1185
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0360 - val_loss: 0.0146 - val_mean_absolute_error: 0.1180
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0358 - val_loss: 0.0144 - val_mean_absolute_error: 0.1175
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0357 - val_loss: 0.0143 - val_mean_absolute_error: 0.1171
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0355 - val_loss: 0.0142 - val_mean_absolute_error: 0.1166
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0353 - val_loss: 0.0141 - val_mean_absolute_error: 0.1161
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0351 - val_loss: 0.0140 - val_mean_absolute_error: 0.1157
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0349 - val_loss: 0.0139 - val_mean_absolute_error: 0.1152
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0348 - val_loss: 0.0138 - val_mean_absolute_error: 0.1147
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0346 - val_loss: 0.0137 - val_mean_absolute_error: 0.1143
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0344 - val_loss: 0.0136 - val_mean_absolute_error: 0.1138
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0342 - val_loss: 0.0135 - val_mean_absolute_error: 0.1134
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0340 - val_loss: 0.0133 - val_mean_absolute_error: 0.1129
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0339 - val_loss: 0.0133 - val_mean_absolute_error: 0.1125
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0337 - val_loss: 0.0132 - val_mean_absolute_error: 0.1121
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0335 - val_loss: 0.0131 - val_mean_absolute_error: 0.1117
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0333 - val_loss: 0.0130 - val_mean_absolute_error: 0.1113
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0332 - val_loss: 0.0129 - val_mean_absolute_error: 0.1109
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0330 - val_loss: 0.0128 - val_mean_absolute_error: 0.1105
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0328 - val_loss: 0.0127 - val_mean_absolute_error: 0.1101
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - mean_absolute_error: 0.0327 - val_loss: 0.0126 - val_mean_absolute_error: 0.1097
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0325 - val_loss: 0.0125 - val_mean_absolute_error: 0.1093
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0324 - val_loss: 0.0124 - val_mean_absolute_error: 0.1089
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - mean_absolute_error: 0.0322 - val_loss: 0.0124 - val_mean_absolute_error: 0.1085
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0320 - val_loss: 0.0123 - val_mean_absolute_error: 0.1082
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0319 - val_loss: 0.0122 - val_mean_absolute_error: 0.1078
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022 - mean_absolute_error: 0.0317 - val_loss: 0.0121 - val_mean_absolute_error: 0.1074
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0315 - val_loss: 0.0120 - val_mean_absolute_error: 0.1070
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0314 - val_loss: 0.0119 - val_mean_absolute_error: 0.1066
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - mean_absolute_error: 0.0312 - val_loss: 0.0119 - val_mean_absolute_error: 0.1063
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0310 - val_loss: 0.0118 - val_mean_absolute_error: 0.1059
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0308 - val_loss: 0.0117 - val_mean_absolute_error: 0.1055
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - mean_absolute_error: 0.0307 - val_loss: 0.0116 - val_mean_absolute_error: 0.1052
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0305 - val_loss: 0.0116 - val_mean_absolute_error: 0.1048
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0303 - val_loss: 0.0115 - val_mean_absolute_error: 0.1045
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - mean_absolute_error: 0.0302 - val_loss: 0.0114 - val_mean_absolute_error: 0.1042
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0300 - val_loss: 0.0113 - val_mean_absolute_error: 0.1039
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0299 - val_loss: 0.0113 - val_mean_absolute_error: 0.1035
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0297 - val_loss: 0.0112 - val_mean_absolute_error: 0.1032
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0296 - val_loss: 0.0111 - val_mean_absolute_error: 0.1029
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020 - mean_absolute_error: 0.0294 - val_loss: 0.0111 - val_mean_absolute_error: 0.1025
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0293 - val_loss: 0.0110 - val_mean_absolute_error: 0.1022
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0292 - val_loss: 0.0109 - val_mean_absolute_error: 0.1019
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0291 - val_loss: 0.0109 - val_mean_absolute_error: 0.1016
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0290 - val_loss: 0.0108 - val_mean_absolute_error: 0.1013

# %% [markdown]
# Training curves 1D CNN

# %%
plot_training_curves(
    market_cnn_history,
    "Market-level 1D CNN"
)

# %% [markdown]
# Test data evaluation 1D CNN

# %%
evaluate_and_plot(
    market_cnn_model,
    trainX_market,
    testX_market,
    trainY_market,
    testY_market,
    scaler_market,
    "Market-level 1D CNN"
)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Market-level 1D CNN Train RMSE: 10858.94
# Market-level 1D CNN Test RMSE: 27010.29

# %% [markdown]
# ### Comparison of RNN vs MLP vs 1D CNN

# %%
rnn_rmse, rnn_mae = evaluate_metrics(
    market_rnn_model,
    testX_market,
    testY_market,
    scaler_market
)

mlp_rmse, mlp_mae = evaluate_metrics(
    market_mlp_model,
    testX_market_mlp,
    testY_market,
    scaler_market
)

cnn_rmse, cnn_mae = evaluate_metrics(
    market_cnn_model,
    testX_market,
    testY_market,
    scaler_market
)

comparison = pd.DataFrame({
    "Model": ["RNN", "MLP", "1D CNN"],
    "RMSE": [rnn_rmse, mlp_rmse, cnn_rmse],
    "MAE": [rnn_mae, mlp_mae, cnn_mae]
})

comparison
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#     Model          RMSE           MAE
# 0     RNN  15985.009573  15295.126984
# 1     MLP  10526.726267   9675.571429
# 2  1D CNN  27010.288619  26676.696429

# %% [markdown]
# ### Your Turn — Build and Compare RNN Models
#
# Choose one or more coherent housing subgroups (for example, 3-bedroom houses) and build at least 3 meaningfully different RNN forecasting models. Evaluate each model using training/validation curves, held-out future test predictions, RMSE, and MAE, and record your observations in markdown cells throughout the notebook.

# %% [markdown]
# ### Model Exploration Summary
#
# Briefly summarize which subgroup(s) and model variations you explored, what changes appeared to improve or worsen forecasting performance, any patterns you noticed in the training curves or predictions, and which model you believe performed best and why.

# %%
# House, 5 bedroom subgroup definition
ma_sequence = house[
    (house["type"] == "house") & (house["bedrooms"] == 5)
].copy()
ma_sequence = ma_sequence.sort_values("saledate").reset_index(drop=True)
                                                                # preserve chronological order

df_subgroup = ma_sequence[["MA"]].copy()                        # univariate forecasting feature

scaler_subgroup = MinMaxScaler(feature_range=(0, 1))
scaled_subgroup = scaler_subgroup.fit_transform(df_subgroup)    # scale feature
                                                                # neural networks train better on scaled values

look_back = 2                                                   # use previous 2 timesteps to predict next timestep

train_size = int(len(scaled_subgroup) * 0.8)                    # splits the dataset into training and test sets using an 80/20 split

train_subgroup = scaled_subgroup[:train_size]                   # earlier historical data
test_subgroup = scaled_subgroup[train_size:]                    # held-out future data

trainX_subgroup, trainY_subgroup = create_sequences(
    train_subgroup,
    look_back
)                                                               # rolling training windows

testX_subgroup, testY_subgroup = create_sequences(
    test_subgroup,
    look_back
)

print("trainX_subgroup shape:", trainX_subgroup.shape)
print("testX_subgroup shape:", testX_subgroup.shape)
# Out:
# trainX_subgroup shape: (37, 2, 1)
# testX_subgroup shape: (8, 2, 1)

# %% [markdown]
# Model 1: Deeper RNN model (extra layer to detect richer insights of temporal data)

# %%
deeper_rnn = Sequential([
    SimpleRNN(16, activation="tanh", return_sequences=True,
              input_shape=(look_back, trainX_subgroup.shape[2])),
    SimpleRNN(8, activation="tanh"),
    Dense(1)
])

deeper_rnn.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

deeper_rnn_history = deeper_rnn.fit(
    trainX_subgroup,
    trainY_subgroup,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/100
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1611 - mean_absolute_error: 0.3567 - val_loss: 1.3701 - val_mean_absolute_error: 1.1535
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0939 - mean_absolute_error: 0.2656 - val_loss: 1.0241 - val_mean_absolute_error: 0.9944
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0499 - mean_absolute_error: 0.1852 - val_loss: 0.7417 - val_mean_absolute_error: 0.8430
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0251 - mean_absolute_error: 0.1161 - val_loss: 0.5271 - val_mean_absolute_error: 0.7071
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153 - mean_absolute_error: 0.0935 - val_loss: 0.3766 - val_mean_absolute_error: 0.5938
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0151 - mean_absolute_error: 0.0972 - val_loss: 0.2805 - val_mean_absolute_error: 0.5089
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0184 - mean_absolute_error: 0.1151 - val_loss: 0.2261 - val_mean_absolute_error: 0.4543
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0208 - mean_absolute_error: 0.1264 - val_loss: 0.2008 - val_mean_absolute_error: 0.4271
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0206 - mean_absolute_error: 0.1263 - val_loss: 0.1943 - val_mean_absolute_error: 0.4204
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0185 - mean_absolute_error: 0.1182 - val_loss: 0.1985 - val_mean_absolute_error: 0.4261
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0158 - mean_absolute_error: 0.1059 - val_loss: 0.2066 - val_mean_absolute_error: 0.4361
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0134 - mean_absolute_error: 0.0942 - val_loss: 0.2135 - val_mean_absolute_error: 0.4445
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0116 - mean_absolute_error: 0.0858 - val_loss: 0.2156 - val_mean_absolute_error: 0.4475
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0103 - mean_absolute_error: 0.0791 - val_loss: 0.2116 - val_mean_absolute_error: 0.4437
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - mean_absolute_error: 0.0738 - val_loss: 0.2017 - val_mean_absolute_error: 0.4333
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0084 - mean_absolute_error: 0.0697 - val_loss: 0.1877 - val_mean_absolute_error: 0.4178
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0077 - mean_absolute_error: 0.0667 - val_loss: 0.1716 - val_mean_absolute_error: 0.3991
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mean_absolute_error: 0.0646 - val_loss: 0.1554 - val_mean_absolute_error: 0.3792
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066 - mean_absolute_error: 0.0632 - val_loss: 0.1404 - val_mean_absolute_error: 0.3598
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0062 - mean_absolute_error: 0.0619 - val_loss: 0.1273 - val_mean_absolute_error: 0.3422
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - mean_absolute_error: 0.0603 - val_loss: 0.1164 - val_mean_absolute_error: 0.3269
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mean_absolute_error: 0.0585 - val_loss: 0.1074 - val_mean_absolute_error: 0.3137
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mean_absolute_error: 0.0568 - val_loss: 0.0999 - val_mean_absolute_error: 0.3023
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mean_absolute_error: 0.0547 - val_loss: 0.0934 - val_mean_absolute_error: 0.2921
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0044 - mean_absolute_error: 0.0524 - val_loss: 0.0875 - val_mean_absolute_error: 0.2826
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mean_absolute_error: 0.0502 - val_loss: 0.0818 - val_mean_absolute_error: 0.2731
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mean_absolute_error: 0.0481 - val_loss: 0.0762 - val_mean_absolute_error: 0.2635
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mean_absolute_error: 0.0462 - val_loss: 0.0708 - val_mean_absolute_error: 0.2537
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0447 - val_loss: 0.0656 - val_mean_absolute_error: 0.2438
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - mean_absolute_error: 0.0433 - val_loss: 0.0606 - val_mean_absolute_error: 0.2341
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0425 - val_loss: 0.0560 - val_mean_absolute_error: 0.2247
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0419 - val_loss: 0.0518 - val_mean_absolute_error: 0.2159
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0412 - val_loss: 0.0481 - val_mean_absolute_error: 0.2076
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0406 - val_loss: 0.0447 - val_mean_absolute_error: 0.2000
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0400 - val_loss: 0.0417 - val_mean_absolute_error: 0.1929
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0393 - val_loss: 0.0391 - val_mean_absolute_error: 0.1864
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0387 - val_loss: 0.0366 - val_mean_absolute_error: 0.1802
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0382 - val_loss: 0.0344 - val_mean_absolute_error: 0.1745
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0378 - val_loss: 0.0324 - val_mean_absolute_error: 0.1691
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0375 - val_loss: 0.0306 - val_mean_absolute_error: 0.1640
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0371 - val_loss: 0.0289 - val_mean_absolute_error: 0.1592
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0368 - val_loss: 0.0274 - val_mean_absolute_error: 0.1548
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0365 - val_loss: 0.0261 - val_mean_absolute_error: 0.1508
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0363 - val_loss: 0.0249 - val_mean_absolute_error: 0.1471
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0360 - val_loss: 0.0239 - val_mean_absolute_error: 0.1437
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0358 - val_loss: 0.0229 - val_mean_absolute_error: 0.1407
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0356 - val_loss: 0.0221 - val_mean_absolute_error: 0.1379
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0353 - val_loss: 0.0214 - val_mean_absolute_error: 0.1355
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0352 - val_loss: 0.0207 - val_mean_absolute_error: 0.1332
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0350 - val_loss: 0.0201 - val_mean_absolute_error: 0.1311
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0348 - val_loss: 0.0196 - val_mean_absolute_error: 0.1293
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - mean_absolute_error: 0.0347 - val_loss: 0.0191 - val_mean_absolute_error: 0.1276
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0345 - val_loss: 0.0187 - val_mean_absolute_error: 0.1262
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0344 - val_loss: 0.0183 - val_mean_absolute_error: 0.1248
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0343 - val_loss: 0.0180 - val_mean_absolute_error: 0.1236
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0342 - val_loss: 0.0177 - val_mean_absolute_error: 0.1226
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0341 - val_loss: 0.0175 - val_mean_absolute_error: 0.1217
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0340 - val_loss: 0.0173 - val_mean_absolute_error: 0.1208
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0339 - val_loss: 0.0171 - val_mean_absolute_error: 0.1201
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0338 - val_loss: 0.0169 - val_mean_absolute_error: 0.1194
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0338 - val_loss: 0.0167 - val_mean_absolute_error: 0.1188
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0337 - val_loss: 0.0166 - val_mean_absolute_error: 0.1183
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0336 - val_loss: 0.0165 - val_mean_absolute_error: 0.1178
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0335 - val_loss: 0.0164 - val_mean_absolute_error: 0.1174
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0334 - val_loss: 0.0163 - val_mean_absolute_error: 0.1170
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0334 - val_loss: 0.0162 - val_mean_absolute_error: 0.1167
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0333 - val_loss: 0.0161 - val_mean_absolute_error: 0.1163
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0018 - mean_absolute_error: 0.0332 - val_loss: 0.0160 - val_mean_absolute_error: 0.1160
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0331 - val_loss: 0.0159 - val_mean_absolute_error: 0.1158
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0331 - val_loss: 0.0159 - val_mean_absolute_error: 0.1155
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0330 - val_loss: 0.0158 - val_mean_absolute_error: 0.1153
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0329 - val_loss: 0.0158 - val_mean_absolute_error: 0.1151
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0329 - val_loss: 0.0157 - val_mean_absolute_error: 0.1149
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0328 - val_loss: 0.0156 - val_mean_absolute_error: 0.1147
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0327 - val_loss: 0.0156 - val_mean_absolute_error: 0.1145
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0326 - val_loss: 0.0156 - val_mean_absolute_error: 0.1143
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0326 - val_loss: 0.0155 - val_mean_absolute_error: 0.1141
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0325 - val_loss: 0.0155 - val_mean_absolute_error: 0.1140
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0324 - val_loss: 0.0154 - val_mean_absolute_error: 0.1138
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0324 - val_loss: 0.0154 - val_mean_absolute_error: 0.1137
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0323 - val_loss: 0.0153 - val_mean_absolute_error: 0.1135
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0322 - val_loss: 0.0153 - val_mean_absolute_error: 0.1133
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0322 - val_loss: 0.0153 - val_mean_absolute_error: 0.1132
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0321 - val_loss: 0.0152 - val_mean_absolute_error: 0.1130
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0320 - val_loss: 0.0152 - val_mean_absolute_error: 0.1129
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0319 - val_loss: 0.0151 - val_mean_absolute_error: 0.1127
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0319 - val_loss: 0.0151 - val_mean_absolute_error: 0.1126
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0318 - val_loss: 0.0151 - val_mean_absolute_error: 0.1125
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0317 - val_loss: 0.0150 - val_mean_absolute_error: 0.1123
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0317 - val_loss: 0.0150 - val_mean_absolute_error: 0.1122
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0316 - val_loss: 0.0150 - val_mean_absolute_error: 0.1120
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0315 - val_loss: 0.0149 - val_mean_absolute_error: 0.1119
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0314 - val_loss: 0.0149 - val_mean_absolute_error: 0.1117
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0314 - val_loss: 0.0148 - val_mean_absolute_error: 0.1116
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - mean_absolute_error: 0.0313 - val_loss: 0.0148 - val_mean_absolute_error: 0.1114
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0312 - val_loss: 0.0148 - val_mean_absolute_error: 0.1113
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0312 - val_loss: 0.0147 - val_mean_absolute_error: 0.1112
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0311 - val_loss: 0.0147 - val_mean_absolute_error: 0.1110
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0310 - val_loss: 0.0147 - val_mean_absolute_error: 0.1109
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - mean_absolute_error: 0.0310 - val_loss: 0.0146 - val_mean_absolute_error: 0.1107

# %%
#training and validation curves
plot_training_curves(
    deeper_rnn_history,
    "Deep RNN"
)

# %% [markdown]
# Very large gap between validation loss/MAE and training loss/MAE. The model definitely overfit on the training data. Also, both curves flatten out after ~40 epochs. 100 epochs is likely not needed.

# %%
#test data evaluation
evaluate_and_plot(
    deeper_rnn,
    trainX_subgroup,
    testX_subgroup,
    trainY_subgroup,
    testY_subgroup,
    scaler_subgroup,
    "Deep RNN"
)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Deep RNN Train RMSE: 18689.50
# Deep RNN Test RMSE: 54828.52

# %% [markdown]
# Pretty large difference between test and train RMSE. The model is underestimating the MA values.

# %% [markdown]
# Model 2: Regularization (dropout and early stopping) applied to deeper model

# %%
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

dropout_rnn = Sequential([
    SimpleRNN(16, activation="tanh", return_sequences=True,
              input_shape=(look_back, trainX_subgroup.shape[2])),
    Dropout(0.2),
    SimpleRNN(8, activation="tanh"),
    Dense(1)
])

dropout_rnn.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

dropout_rnn_history = dropout_rnn.fit(
    trainX_subgroup,
    trainY_subgroup,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0443 - mean_absolute_error: 0.1701 - val_loss: 0.2328 - val_mean_absolute_error: 0.4723
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0254 - mean_absolute_error: 0.1080 - val_loss: 0.1209 - val_mean_absolute_error: 0.3372
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0104 - mean_absolute_error: 0.0800 - val_loss: 0.0575 - val_mean_absolute_error: 0.2283
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0217 - mean_absolute_error: 0.1085 - val_loss: 0.0314 - val_mean_absolute_error: 0.1646
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0152 - mean_absolute_error: 0.1058 - val_loss: 0.0236 - val_mean_absolute_error: 0.1410
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0157 - mean_absolute_error: 0.0923 - val_loss: 0.0218 - val_mean_absolute_error: 0.1354
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0175 - mean_absolute_error: 0.0973 - val_loss: 0.0197 - val_mean_absolute_error: 0.1286
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0116 - mean_absolute_error: 0.0881 - val_loss: 0.0190 - val_mean_absolute_error: 0.1268
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0143 - mean_absolute_error: 0.0869 - val_loss: 0.0202 - val_mean_absolute_error: 0.1323
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mean_absolute_error: 0.0703 - val_loss: 0.0237 - val_mean_absolute_error: 0.1452
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - mean_absolute_error: 0.0698 - val_loss: 0.0303 - val_mean_absolute_error: 0.1662
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0087 - mean_absolute_error: 0.0618 - val_loss: 0.0325 - val_mean_absolute_error: 0.1728
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mean_absolute_error: 0.0568 - val_loss: 0.0308 - val_mean_absolute_error: 0.1684
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - mean_absolute_error: 0.0508 - val_loss: 0.0278 - val_mean_absolute_error: 0.1597
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060 - mean_absolute_error: 0.0533 - val_loss: 0.0232 - val_mean_absolute_error: 0.1451
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0359 - val_loss: 0.0182 - val_mean_absolute_error: 0.1276
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0573 - val_loss: 0.0161 - val_mean_absolute_error: 0.1193
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mean_absolute_error: 0.0520 - val_loss: 0.0129 - val_mean_absolute_error: 0.1060
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mean_absolute_error: 0.0556 - val_loss: 0.0108 - val_mean_absolute_error: 0.0963
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mean_absolute_error: 0.0426 - val_loss: 0.0109 - val_mean_absolute_error: 0.0969
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mean_absolute_error: 0.0436 - val_loss: 0.0124 - val_mean_absolute_error: 0.1044
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040 - mean_absolute_error: 0.0449 - val_loss: 0.0134 - val_mean_absolute_error: 0.1092
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mean_absolute_error: 0.0471 - val_loss: 0.0119 - val_mean_absolute_error: 0.1026
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mean_absolute_error: 0.0599 - val_loss: 0.0101 - val_mean_absolute_error: 0.0941
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - mean_absolute_error: 0.0672 - val_loss: 0.0095 - val_mean_absolute_error: 0.0908
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mean_absolute_error: 0.0455 - val_loss: 0.0087 - val_mean_absolute_error: 0.0866
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mean_absolute_error: 0.0483 - val_loss: 0.0082 - val_mean_absolute_error: 0.0837
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mean_absolute_error: 0.0444 - val_loss: 0.0075 - val_mean_absolute_error: 0.0797
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mean_absolute_error: 0.0467 - val_loss: 0.0087 - val_mean_absolute_error: 0.0871
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - mean_absolute_error: 0.0481 - val_loss: 0.0096 - val_mean_absolute_error: 0.0919
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0434 - val_loss: 0.0086 - val_mean_absolute_error: 0.0865
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0409 - val_loss: 0.0077 - val_mean_absolute_error: 0.0812
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mean_absolute_error: 0.0440 - val_loss: 0.0085 - val_mean_absolute_error: 0.0858
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mean_absolute_error: 0.0459 - val_loss: 0.0091 - val_mean_absolute_error: 0.0890
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - mean_absolute_error: 0.0464 - val_loss: 0.0089 - val_mean_absolute_error: 0.0882
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mean_absolute_error: 0.0502 - val_loss: 0.0082 - val_mean_absolute_error: 0.0842
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mean_absolute_error: 0.0558 - val_loss: 0.0079 - val_mean_absolute_error: 0.0830
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mean_absolute_error: 0.0439 - val_loss: 0.0080 - val_mean_absolute_error: 0.0837

# %%
#training and validation curves
plot_training_curves(
    dropout_rnn_history,
    "Deep RNN with Regularization"
)

# %% [markdown]
# Regularization certainly helped the deeper model. There is much less of a gap between the training loss/MAE and validation loss/MAE. As expected, 100 epochs was not needed. Early stopping made training stop at 38 epochs.

# %%
#test data evaluation
evaluate_and_plot(
    dropout_rnn,
    trainX_subgroup,
    testX_subgroup,
    trainY_subgroup,
    testY_subgroup,
    scaler_subgroup,
    "Deep RNN with Regularization"
)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Deep RNN with Regularization Train RMSE: 14638.16
# Deep RNN with Regularization Test RMSE: 34585.80

# %% [markdown]
# Better/closer predictions this time around. Test RMSE isn't as high as the previous model.

# %% [markdown]
# Model 3: Larger lookback window

# %%
look_back = 6                                                   # use previous 6 timesteps to predict next timestep

train_size = int(len(scaled_subgroup) * 0.8)                    # splits the dataset into training and test sets using an 80/20 split

train_subgroup = scaled_subgroup[:train_size]                   # earlier historical data
test_subgroup = scaled_subgroup[train_size:]                    # held-out future data

trainX_subgroup, trainY_subgroup = create_sequences(
    train_subgroup,
    look_back
)                                                               # rolling training windows

testX_subgroup, testY_subgroup = create_sequences(
    test_subgroup,
    look_back
)

print("trainX_subgroup shape:", trainX_subgroup.shape)
print("testX_subgroup shape:", testX_subgroup.shape)
# Out:
# trainX_subgroup shape: (33, 6, 1)
# testX_subgroup shape: (4, 6, 1)

# %%
lookback_model = Sequential([
    SimpleRNN(
        16, 
        activation="tanh", 
        input_shape=(look_back, trainX_subgroup.shape[2]) 
    ),                                                          

    Dense(1)                                                   
])

lookback_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

lookback_model_history = lookback_model.fit(
    trainX_subgroup,
    trainY_subgroup,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,                                             
    verbose=1
)
# Out:
# Epoch 1/100
# /Users/donyabehroozi/Documents/gsb545/GSB-545/tf_env/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0039 - mean_absolute_error: 0.0571 - val_loss: 1.3957e-04 - val_mean_absolute_error: 0.0110
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - mean_absolute_error: 0.0433 - val_loss: 0.0038 - val_mean_absolute_error: 0.0598
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - mean_absolute_error: 0.0412 - val_loss: 1.0903e-04 - val_mean_absolute_error: 0.0082
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1313e-04 - mean_absolute_error: 0.0243 - val_loss: 0.0025 - val_mean_absolute_error: 0.0490
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0276 - val_loss: 0.0015 - val_mean_absolute_error: 0.0370
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9311e-04 - mean_absolute_error: 0.0209 - val_loss: 1.3878e-04 - val_mean_absolute_error: 0.0104
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0374e-04 - mean_absolute_error: 0.0216 - val_loss: 8.2576e-04 - val_mean_absolute_error: 0.0256
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0952e-04 - mean_absolute_error: 0.0230 - val_loss: 4.7747e-04 - val_mean_absolute_error: 0.0178
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7661e-04 - mean_absolute_error: 0.0200 - val_loss: 1.4401e-04 - val_mean_absolute_error: 0.0097
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5215e-04 - mean_absolute_error: 0.0203 - val_loss: 1.6199e-04 - val_mean_absolute_error: 0.0103
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3040e-04 - mean_absolute_error: 0.0195 - val_loss: 2.2465e-04 - val_mean_absolute_error: 0.0132
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0751e-04 - mean_absolute_error: 0.0183 - val_loss: 5.7373e-04 - val_mean_absolute_error: 0.0197
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2657e-04 - mean_absolute_error: 0.0186 - val_loss: 5.7009e-04 - val_mean_absolute_error: 0.0196
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9241e-04 - mean_absolute_error: 0.0183 - val_loss: 3.3368e-04 - val_mean_absolute_error: 0.0153
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8029e-04 - mean_absolute_error: 0.0184 - val_loss: 2.7336e-04 - val_mean_absolute_error: 0.0142
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7300e-04 - mean_absolute_error: 0.0180 - val_loss: 3.8915e-04 - val_mean_absolute_error: 0.0161
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6353e-04 - mean_absolute_error: 0.0177 - val_loss: 5.3376e-04 - val_mean_absolute_error: 0.0189
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5950e-04 - mean_absolute_error: 0.0176 - val_loss: 4.9780e-04 - val_mean_absolute_error: 0.0183
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5000e-04 - mean_absolute_error: 0.0175 - val_loss: 3.9836e-04 - val_mean_absolute_error: 0.0163
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4513e-04 - mean_absolute_error: 0.0174 - val_loss: 3.9472e-04 - val_mean_absolute_error: 0.0163
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3872e-04 - mean_absolute_error: 0.0172 - val_loss: 4.6580e-04 - val_mean_absolute_error: 0.0179
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3355e-04 - mean_absolute_error: 0.0171 - val_loss: 4.9647e-04 - val_mean_absolute_error: 0.0185
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2903e-04 - mean_absolute_error: 0.0170 - val_loss: 4.5866e-04 - val_mean_absolute_error: 0.0178
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2503e-04 - mean_absolute_error: 0.0169 - val_loss: 4.3828e-04 - val_mean_absolute_error: 0.0175
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2086e-04 - mean_absolute_error: 0.0169 - val_loss: 4.6706e-04 - val_mean_absolute_error: 0.0181
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1640e-04 - mean_absolute_error: 0.0167 - val_loss: 4.9521e-04 - val_mean_absolute_error: 0.0187
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1275e-04 - mean_absolute_error: 0.0166 - val_loss: 4.8773e-04 - val_mean_absolute_error: 0.0186
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0958e-04 - mean_absolute_error: 0.0166 - val_loss: 4.7710e-04 - val_mean_absolute_error: 0.0184
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0626e-04 - mean_absolute_error: 0.0166 - val_loss: 4.8998e-04 - val_mean_absolute_error: 0.0187
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0263e-04 - mean_absolute_error: 0.0165 - val_loss: 5.0608e-04 - val_mean_absolute_error: 0.0190
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9941e-04 - mean_absolute_error: 0.0164 - val_loss: 5.0465e-04 - val_mean_absolute_error: 0.0190
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9659e-04 - mean_absolute_error: 0.0164 - val_loss: 4.9942e-04 - val_mean_absolute_error: 0.0189
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9368e-04 - mean_absolute_error: 0.0164 - val_loss: 5.0459e-04 - val_mean_absolute_error: 0.0191
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9060e-04 - mean_absolute_error: 0.0163 - val_loss: 5.1041e-04 - val_mean_absolute_error: 0.0192
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8775e-04 - mean_absolute_error: 0.0162 - val_loss: 5.0744e-04 - val_mean_absolute_error: 0.0192
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8514e-04 - mean_absolute_error: 0.0162 - val_loss: 5.0318e-04 - val_mean_absolute_error: 0.0191
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8246e-04 - mean_absolute_error: 0.0162 - val_loss: 5.0353e-04 - val_mean_absolute_error: 0.0191
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7971e-04 - mean_absolute_error: 0.0162 - val_loss: 5.0287e-04 - val_mean_absolute_error: 0.0192
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7713e-04 - mean_absolute_error: 0.0162 - val_loss: 4.9807e-04 - val_mean_absolute_error: 0.0191
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7464e-04 - mean_absolute_error: 0.0161 - val_loss: 4.9360e-04 - val_mean_absolute_error: 0.0190
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7211e-04 - mean_absolute_error: 0.0161 - val_loss: 4.9091e-04 - val_mean_absolute_error: 0.0190
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6958e-04 - mean_absolute_error: 0.0161 - val_loss: 4.8681e-04 - val_mean_absolute_error: 0.0189
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6715e-04 - mean_absolute_error: 0.0161 - val_loss: 4.8110e-04 - val_mean_absolute_error: 0.0189
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6474e-04 - mean_absolute_error: 0.0161 - val_loss: 4.7606e-04 - val_mean_absolute_error: 0.0188
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6232e-04 - mean_absolute_error: 0.0161 - val_loss: 4.7128e-04 - val_mean_absolute_error: 0.0187
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5994e-04 - mean_absolute_error: 0.0160 - val_loss: 4.6540e-04 - val_mean_absolute_error: 0.0186
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5760e-04 - mean_absolute_error: 0.0160 - val_loss: 4.5915e-04 - val_mean_absolute_error: 0.0185
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5527e-04 - mean_absolute_error: 0.0160 - val_loss: 4.5325e-04 - val_mean_absolute_error: 0.0184
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5295e-04 - mean_absolute_error: 0.0160 - val_loss: 4.4702e-04 - val_mean_absolute_error: 0.0183
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5067e-04 - mean_absolute_error: 0.0159 - val_loss: 4.4026e-04 - val_mean_absolute_error: 0.0182
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4841e-04 - mean_absolute_error: 0.0159 - val_loss: 4.3356e-04 - val_mean_absolute_error: 0.0181
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4616e-04 - mean_absolute_error: 0.0159 - val_loss: 4.2687e-04 - val_mean_absolute_error: 0.0179
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4394e-04 - mean_absolute_error: 0.0159 - val_loss: 4.1986e-04 - val_mean_absolute_error: 0.0178
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4174e-04 - mean_absolute_error: 0.0158 - val_loss: 4.1276e-04 - val_mean_absolute_error: 0.0177
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3956e-04 - mean_absolute_error: 0.0158 - val_loss: 4.0573e-04 - val_mean_absolute_error: 0.0175
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3740e-04 - mean_absolute_error: 0.0158 - val_loss: 3.9859e-04 - val_mean_absolute_error: 0.0174
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3527e-04 - mean_absolute_error: 0.0157 - val_loss: 3.9137e-04 - val_mean_absolute_error: 0.0173
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3315e-04 - mean_absolute_error: 0.0157 - val_loss: 3.8420e-04 - val_mean_absolute_error: 0.0171
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3105e-04 - mean_absolute_error: 0.0157 - val_loss: 3.7703e-04 - val_mean_absolute_error: 0.0170
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2898e-04 - mean_absolute_error: 0.0157 - val_loss: 3.6983e-04 - val_mean_absolute_error: 0.0168
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2693e-04 - mean_absolute_error: 0.0156 - val_loss: 3.6268e-04 - val_mean_absolute_error: 0.0167
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2490e-04 - mean_absolute_error: 0.0156 - val_loss: 3.5559e-04 - val_mean_absolute_error: 0.0165
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2289e-04 - mean_absolute_error: 0.0156 - val_loss: 3.4851e-04 - val_mean_absolute_error: 0.0163
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2091e-04 - mean_absolute_error: 0.0155 - val_loss: 3.4149e-04 - val_mean_absolute_error: 0.0162
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1894e-04 - mean_absolute_error: 0.0155 - val_loss: 3.3455e-04 - val_mean_absolute_error: 0.0160
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1700e-04 - mean_absolute_error: 0.0155 - val_loss: 3.2767e-04 - val_mean_absolute_error: 0.0159
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1508e-04 - mean_absolute_error: 0.0154 - val_loss: 3.2087e-04 - val_mean_absolute_error: 0.0157
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1319e-04 - mean_absolute_error: 0.0154 - val_loss: 3.1416e-04 - val_mean_absolute_error: 0.0155
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1132e-04 - mean_absolute_error: 0.0154 - val_loss: 3.0753e-04 - val_mean_absolute_error: 0.0154
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0947e-04 - mean_absolute_error: 0.0153 - val_loss: 3.0100e-04 - val_mean_absolute_error: 0.0152
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0764e-04 - mean_absolute_error: 0.0153 - val_loss: 2.9458e-04 - val_mean_absolute_error: 0.0151
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0584e-04 - mean_absolute_error: 0.0153 - val_loss: 2.8826e-04 - val_mean_absolute_error: 0.0149
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0406e-04 - mean_absolute_error: 0.0152 - val_loss: 2.8206e-04 - val_mean_absolute_error: 0.0147
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0230e-04 - mean_absolute_error: 0.0152 - val_loss: 2.7596e-04 - val_mean_absolute_error: 0.0146
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0057e-04 - mean_absolute_error: 0.0152 - val_loss: 2.6999e-04 - val_mean_absolute_error: 0.0144
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9887e-04 - mean_absolute_error: 0.0151 - val_loss: 2.6413e-04 - val_mean_absolute_error: 0.0142
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9718e-04 - mean_absolute_error: 0.0151 - val_loss: 2.5840e-04 - val_mean_absolute_error: 0.0141
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9552e-04 - mean_absolute_error: 0.0151 - val_loss: 2.5279e-04 - val_mean_absolute_error: 0.0139
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9389e-04 - mean_absolute_error: 0.0151 - val_loss: 2.4731e-04 - val_mean_absolute_error: 0.0137
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9228e-04 - mean_absolute_error: 0.0150 - val_loss: 2.4195e-04 - val_mean_absolute_error: 0.0136
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9069e-04 - mean_absolute_error: 0.0150 - val_loss: 2.3673e-04 - val_mean_absolute_error: 0.0134
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8912e-04 - mean_absolute_error: 0.0150 - val_loss: 2.3163e-04 - val_mean_absolute_error: 0.0132
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8758e-04 - mean_absolute_error: 0.0149 - val_loss: 2.2667e-04 - val_mean_absolute_error: 0.0131
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8607e-04 - mean_absolute_error: 0.0149 - val_loss: 2.2184e-04 - val_mean_absolute_error: 0.0129
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8458e-04 - mean_absolute_error: 0.0149 - val_loss: 2.1714e-04 - val_mean_absolute_error: 0.0127
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8311e-04 - mean_absolute_error: 0.0148 - val_loss: 2.1257e-04 - val_mean_absolute_error: 0.0126
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8166e-04 - mean_absolute_error: 0.0148 - val_loss: 2.0814e-04 - val_mean_absolute_error: 0.0124
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8024e-04 - mean_absolute_error: 0.0148 - val_loss: 2.0383e-04 - val_mean_absolute_error: 0.0122
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7884e-04 - mean_absolute_error: 0.0148 - val_loss: 1.9967e-04 - val_mean_absolute_error: 0.0121
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7746e-04 - mean_absolute_error: 0.0147 - val_loss: 1.9562e-04 - val_mean_absolute_error: 0.0119
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7611e-04 - mean_absolute_error: 0.0147 - val_loss: 1.9171e-04 - val_mean_absolute_error: 0.0117
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7477e-04 - mean_absolute_error: 0.0147 - val_loss: 1.8793e-04 - val_mean_absolute_error: 0.0116
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7346e-04 - mean_absolute_error: 0.0147 - val_loss: 1.8428e-04 - val_mean_absolute_error: 0.0114
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7218e-04 - mean_absolute_error: 0.0147 - val_loss: 1.8076e-04 - val_mean_absolute_error: 0.0113
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7091e-04 - mean_absolute_error: 0.0147 - val_loss: 1.7735e-04 - val_mean_absolute_error: 0.0111
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6966e-04 - mean_absolute_error: 0.0146 - val_loss: 1.7408e-04 - val_mean_absolute_error: 0.0109
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6844e-04 - mean_absolute_error: 0.0146 - val_loss: 1.7092e-04 - val_mean_absolute_error: 0.0108
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6724e-04 - mean_absolute_error: 0.0146 - val_loss: 1.6789e-04 - val_mean_absolute_error: 0.0106
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6605e-04 - mean_absolute_error: 0.0146 - val_loss: 1.6497e-04 - val_mean_absolute_error: 0.0106
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6489e-04 - mean_absolute_error: 0.0146 - val_loss: 1.6217e-04 - val_mean_absolute_error: 0.0105

# %%
#training and validation curves
plot_training_curves(
    lookback_model_history,
    "RNN with Larger Lookback"
)

# %% [markdown]
# This is the closest the training loss/MAE and validation loss/MAE have ever been. Extremely little to no gap between the curves. Early stopping could have helped though, the curves flatten out much earlier than 100 epochs.

# %%
#test data evaluation
evaluate_and_plot(
    lookback_model,
    trainX_subgroup,
    testX_subgroup,
    trainY_subgroup,
    testY_subgroup,
    scaler_subgroup,
    "RNN with Larger Lookback"
)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# RNN with Larger Lookback Train RMSE: 5043.77
# RNN with Larger Lookback Test RMSE: 14848.50

# %% [markdown]
# This is the closest the predictions have been to the actual MA values, and the closest the train/test RMSE have been to each other across all three models.

# %% [markdown]
# Overall summary:
#
# For this experiment, I explored the house, 5 bedroom subgroup and the following 3 models:
# - Deeper RNN with an extra layer
# - Deeper RNN with an extra layer + regularization applied (dropout and early stopping)
# - RNN with lookback = 6 instead of 2
#
# Forecasting performance was certainly improved by adding regularization (early stopping and dropout) along with a larger lookback. It seems like adding an extra layer to the RNN with up to 100 epochs worsened performance, likely because the model overfit the training data. In the training and validation curves, I noticed that training loss/MAE was almost always below the validation loss/MAE which indicates that there was always some level of the model overfitting the training data. I also noticed that 100 epochs was too much for this model. The curves always flattened out much earlier. In fact, the early stopping made training of my second model stop at 38 epochs. With regards to the predictions, I noticed that models 1 and 2 underestimated the actual MA values. Overall, I would say that the third model (RNN with lookback = 6 instead of 2) performed the best. This model had the closest training loss/MAE and validation loss/MAE curves, the most accurate predictions, and the smallest difference between train and test RMSE.
